# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten
# Out:
# /Users/jasminecjwchen/Documents/GitHub/COMS4995-AML-Project/.venv/lib/python3.9/site-packages/urllib3/__init__.py:34: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import random
import math

# %%
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.calibration import LabelEncoder
from sklearn.metrics import roc_auc_score

# %%
from scikeras.wrappers import KerasClassifier

# %%
# %matplotlib inline
sns.set_theme()

# %%
df = pd.read_csv("kaggle_survey_2020_responses.csv")

# %%
salary_data = df.drop(columns = ["time_from_start_to_finish_seconds"])

# %%
salary_data = salary_data.dropna(subset = ["q24"])

# %%
salary_data_as_num = pd.DataFrame()

# %%
def convert_to_category(col_name: str, order_rules: list, data):
    data[col_name] = pd.Categorical(data[col_name], order_rules)

# %%
def convert_to_category_no_specified_order(col_name, data):
    if sum(data[col_name].isna().astype(int)) > 0:
        data[col_name].fillna("No response", inplace = True)
    
    order = list(set(data[col_name]))
    convert_to_category(col_name, order, data)

# %%
def convert_category_to_code(col_name: str, data, inplace = False):
    if inplace:
        data[col_name] = data[col_name].cat.codes + 1 # because NaN automatically becomes -1
    else:
        return data[col_name].cat.codes + 1

# %%
def process_column(col_name: str, order_rules = None, data = salary_data, num_data = salary_data_as_num):
    if order_rules:
        convert_to_category(col_name, order_rules, data)
    else:
        convert_to_category_no_specified_order(col_name, data)
    num_data[col_name] = convert_category_to_code(col_name, data)

# %%
def one_hot_column_to_binary(col_name, data = salary_data):
    data[col_name].fillna(0, inplace = True)
    data[col_name].mask(data[col_name] != 0, 1, inplace = True)

# %%
def process_one_hot_encoded_columns(columns, data = salary_data, num_data = salary_data_as_num):
    for col in columns:
        one_hot_column_to_binary(col, data)
        num_data[col] = data[col]

# %%
def column_text_to_binary(col_name, data = salary_data, num_data = salary_data_as_num):
    data[col_name] = data[col_name].notna().astype(int)
    num_data[col_name] = data[col_name]

# %%
def combine_multiple_columns_into_one_binary(columns, new_col_name, data = salary_data, num_data = salary_data_as_num):
    for col_name in columns:
        one_hot_column_to_binary(col_name)
        
    data[new_col_name] = data[columns].sum(axis = 1)
    data[new_col_name] = data[new_col_name].astype(int)
    
    data[new_col_name].mask(data[new_col_name] > 0, 1, inplace = True)
    num_data[new_col_name] = data[new_col_name]

# %% [markdown]
# ## Q24 Target Column

# %% [markdown]
# ### v1: original bins

# %%
q24_order = ["$0-999",
             '1,000-1,999',
             '2,000-2,999',
             '3,000-3,999',
             '4,000-4,999',
             '5,000-7,499',
             '7,500-9,999',
             '10,000-14,999',
             '15,000-19,999',
             '20,000-24,999',
             '25,000-29,999',
             '30,000-39,999',
             '40,000-49,999',
             '50,000-59,999',
              '60,000-69,999',
              '70,000-79,999',
              '80,000-89,999',
              '90,000-99,999',
            '100,000-124,999',
            '125,000-149,999',
            '150,000-199,999',
             '200,000-249,999',
             '250,000-299,999',
              '300,000-500,000',
              '> $500,000'
             ]

# %% [markdown]
# ## v2: numerical

# %%
q24_mapped_to = [
    1, #"$0-999",
    1, #        '1,000-1,999',
    1, #         '2,000-2,999',
    1, #         '3,000-3,999',
    1, #         '4,000-4,999',
    1, #        '5,000-7,499',
    1, #         '7,500-9,999',
    2, #         '10,000-14,999',
    2, #         '15,000-19,999',
    2, #         '20,000-24,999',
    2, #         '25,000-29,999',
    2, #         '30,000-39,999',
    2, #         '40,000-49,999',
    2, #         '50,000-59,999',
    2, #          '60,000-69,999',
    2, #          '70,000-79,999',
    2, #          '80,000-89,999',
    2, #          '90,000-99,999',
    3, #        '100,000-124,999',
    3, #        '125,000-149,999',
    3, #        '150,000-199,999',
    3, #         '200,000-249,999',
    3, #         '250,000-299,999',
    3, #          '300,000-500,000',
    4 #          '> $500,000'
]

# %%
q24_mapping = dict(zip(q24_order, q24_mapped_to))

# %%
test_col = salary_data["q24"].copy()
test_col
# Out:
# 1        100,000-124,999
# 2          15,000-19,999
# 3        125,000-149,999
# 8          70,000-79,999
# 11         30,000-39,999
#               ...
# 20024        2,000-2,999
# 20029      15,000-19,999
# 20033             $0-999
# 20034             $0-999
# 20035             $0-999
# Name: q24, Length: 10729, dtype: object

# %%
test_col = test_col.replace(q24_mapping)

# %%
salary_data["q24"] = test_col
salary_data_as_num["q24"] = test_col

# %% [markdown]
# ## Q1 Age

# %%
salary_data["q1"].value_counts()
# Out:
# q1
# 25-29    2350
# 30-34    1979
# 35-39    1467
# 22-24    1424
# 40-44    1042
# 45-49     771
# 50-54     536
# 18-21     498
# 60-69     309
# 55-59     301
# 70         52
# Name: count, dtype: int64

# %%
q1_order = [
    "18-21",
    "22-24",
    "25-29",
    "30-34",
    "35-39",
    "40-44",
    "45-49",
    "50-54",
    "55-59",
    "60-69",
    "70"
]

# %%
convert_to_category("q1", q1_order, salary_data)

# %%
salary_data_as_num["q1"] = convert_category_to_code("q1", salary_data, False)
salary_data_as_num
# Out:
#        q24  q1
# 1        3   4
# 2        2   5
# 3        3   4
# 8        2   5
# 11       2   5
# ...    ...  ..
# 20024    1   5
# 20029    2   5
# 20033    1   4
# 20034    1   2
# 20035    1   2
#
# [10729 rows x 2 columns]

# %%
salary_data_as_num["q1"].value_counts()
# Out:
# q1
# 3     2350
# 4     1979
# 5     1467
# 2     1424
# 6     1042
# 7      771
# 8      536
# 1      498
# 10     309
# 9      301
# 11      52
# Name: count, dtype: int64

# %% [markdown]
# ## Q2 Gender

# %%
salary_data["q2"].value_counts()
# Out:
# q2
# Man                        8872
# Woman                      1683
# Prefer not to say           131
# Prefer to self-describe      23
# Nonbinary                    20
# Name: count, dtype: int64

# %%
q2_order = ['Man', "Woman", "Nonbinary", 'Prefer to self-describe', 'Prefer not to say']

# %%
convert_to_category("q2", q2_order, salary_data)

# %%
salary_data_as_num["q2"] = convert_category_to_code("q2", salary_data, False)
salary_data_as_num
# Out:
#        q24  q1  q2
# 1        3   4   1
# 2        2   5   1
# 3        3   4   1
# 8        2   5   1
# 11       2   5   1
# ...    ...  ..  ..
# 20024    1   5   1
# 20029    2   5   1
# 20033    1   4   1
# 20034    1   2   1
# 20035    1   2   1
#
# [10729 rows x 3 columns]

# %%
salary_data_as_num["q2"].value_counts()
# Out:
# q2
# 1    8872
# 2    1683
# 5     131
# 4      23
# 3      20
# Name: count, dtype: int64

# %% [markdown]
# ## Q3 Country

# %%
convert_to_category_no_specified_order("q3", salary_data)

# %%
salary_data_as_num["q3"] = convert_category_to_code("q3", salary_data)

# %% [markdown]
# ## Q4 Education

# %%
salary_data["q4"].value_counts()
# Out:
# q4
# Master’s degree                                                      4879
# Bachelor’s degree                                                    3013
# Doctoral degree                                                      1718
# Professional degree                                                   470
# Some college/university study without earning a bachelor’s degree     385
# I prefer not to answer                                                158
# No formal education past high school                                  106
# Name: count, dtype: int64

# %%
q4_order = ["No formal education past high school",
            "Some college/university study without earning a bachelor’s degree",
            "Professional degree",
            "Bachelor’s degree",
            "Master’s degree",
            "Doctoral degree",
            "I prefer not to answer"
            ]

# %%
convert_to_category("q4", q4_order, salary_data)

# %%
salary_data_as_num["q4"] = convert_category_to_code("q4", salary_data)

# %%
salary_data_as_num["q4"].value_counts()
# Out:
# q4
# 5    4879
# 4    3013
# 6    1718
# 3     470
# 2     385
# 7     158
# 1     106
# Name: count, dtype: int64

# %% [markdown]
# ## Q5 Job Title

# %%
salary_data["q5"].value_counts()
# Out:
# q5
# Data Scientist               2398
# Software Engineer            1620
# Other                        1508
# Data Analyst                 1260
# Research Scientist           1028
# Machine Learning Engineer     918
# Business Analyst              678
# Product/Project Manager       590
# Data Engineer                 369
# Statistician                  248
# DBA/Database Engineer         112
# Name: count, dtype: int64

# %%
convert_to_category_no_specified_order("q5", salary_data)

# %%
salary_data_as_num["q5"] = convert_category_to_code("q5", salary_data)

# %% [markdown]
# ## Q6 Years Coding

# %%
q6_order = [
 'I have never written code',
 '< 1 years',
 '1-2 years',
 '3-5 years',
 '5-10 years',
 '10-20 years',
 '20+ years']

# %%
process_column("q6", q6_order)

# %% [markdown]
# ## Q7 Language

# %%
q7_columns = [
     'q7_part_1',
 'q7_part_2',
 'q7_part_3',
 'q7_part_4',
 'q7_part_5',
 'q7_part_6',
 'q7_part_7',
 'q7_part_8',
 'q7_part_9',
 'q7_part_10',
 'q7_part_11',
 'q7_part_12',
 'q7_other'
]

# %%
process_one_hot_encoded_columns(q7_columns)

# %% [markdown]
# ## Q11 Computing Platform

# %%
process_column("q11")

# %% [markdown]
# ## Q12 Specialized Hardware

# %%
q12_columns = [
    'q12_part_1',
 'q12_part_2',
 'q12_part_3',
 'q12_other'
]

# %%
process_one_hot_encoded_columns(q12_columns)

# %% [markdown]
# ## Q14 Visualization

# %%
q14_columns = [
    'q14_part_1',
 'q14_part_2',
 'q14_part_3',
 'q14_part_4',
 'q14_part_5',
 'q14_part_6',
 'q14_part_7',
 'q14_part_8',
 'q14_part_9',
 'q14_part_10',
 'q14_part_11',
 'q14_other'
]

# %%
process_one_hot_encoded_columns(q14_columns)

# %% [markdown]
# ## Q15 Years ML

# %%
q15_order = [
    'I do not use machine learning methods',
    'Under 1 year',
    '1-2 years',
    '2-3 years',
    '3-4 years',
    '4-5 years',
    '5-10 years',
    '10-20 years',
    '20 or more years'
]

# %%
process_column("q15", q15_order)

# %% [markdown]
# ## Q17 ML Algorithms

# %%
q17_columns = [
    'q17_part_1',
 'q17_part_2',
 'q17_part_3',
 'q17_part_4',
 'q17_part_5',
 'q17_part_6',
 'q17_part_7',
 'q17_part_8',
 'q17_part_9',
 'q17_part_10',
 'q17_part_11',
 'q17_other'
]

# %%
process_one_hot_encoded_columns(q17_columns)

# %% [markdown]
# ## Q20 Company Size

# %%
q20_order = [
    '0-49 employees',
    '50-249 employees',
    '250-999 employees',
    '1000-9,999 employees',
    '10,000 or more employees'
]

# %%
process_column("q20", q20_order)

# %% [markdown]
# ## Q21 Datascience Workloads

# %%
q21_order = [
    '0',
    '1-2',
    '3-4',
    '5-9',
    '10-14',
    '15-19',
    '20'
]

# %%
process_column("q21", q21_order)

# %% [markdown]
# ## Q22 Incorporating ML

# %% [markdown]
# i'm not super sure about the proper "order" for this question. Feel free to change this if you find it more appropriate. Just please let the chat know in case it affects others' encoding.

# %%
q22_order = [
    'I do not know',
    'No (we do not use ML methods)',
    'We are exploring ML methods (and may one day put a model into production)',
    'We use ML methods for generating insights (but do not put working models into production)',
    'We recently started using ML methods (i.e., models in production for less than 2 years)',
    'We have well established ML methods (i.e., models in production for more than 2 years)'
]

# %%
process_column("q22", q22_order)

# %% [markdown]
# ## Q30 Big Data Products

# %%
column_text_to_binary("q30")

# %% [markdown]
# ## Q32 Business Intelligence Tools

# %%
column_text_to_binary("q32")

# %% [markdown]
# ## Q33 Automated ML Tools

# %%
q33_columns = [
    'q33_a_part_1',
 'q33_a_part_2',
 'q33_a_part_3',
 'q33_a_part_4',
 'q33_a_part_5',
 'q33_a_part_6',
 'q33_a_part_7',
 'q33_a_other'
]

# %%
combine_multiple_columns_into_one_binary(q33_columns, "q33")

# %% [markdown]
# ## Q37 Data Science Courses

# %%
q37_columns = [
    'q37_part_1',
 'q37_part_2',
 'q37_part_3',
 'q37_part_4',
 'q37_part_5',
 'q37_part_6',
 'q37_part_7',
 'q37_part_8',
 'q37_part_9',
 'q37_part_10',
 'q37_part_11',
 'q37_other'
]

# %%
process_one_hot_encoded_columns(q37_columns)

# %% [markdown]
# ## Q38 Primary Data Analysis Tool

# %%
process_column("q38")

# %% [markdown]
# ## Q39 Media Sources

# %%
q39_columns = [
    'q39_part_1',
 'q39_part_2',
 'q39_part_3',
 'q39_part_4',
 'q39_part_5',
 'q39_part_6',
 'q39_part_7',
 'q39_part_8',
 'q39_part_9',
 'q39_part_10',
 'q39_part_11',
 'q39_other'
]

# %%
process_one_hot_encoded_columns(q39_columns)

# %% [markdown]
# ## Dropped Columns

# %%
one_hot_dropped = [
    'q33_a_part_1',
 'q33_a_part_2',
 'q33_a_part_3',
 'q33_a_part_4',
 'q33_a_part_5',
 'q33_a_part_6',
 'q33_a_part_7',
 'q33_a_other',
]

# %%
dropped_questions = [
    "q8",
    'q9_part_1',
 'q9_part_2',
 'q9_part_3',
 'q9_part_4',
 'q9_part_5',
 'q9_part_6',
 'q9_part_7',
 'q9_part_8',
 'q9_part_9',
 'q9_part_10',
 'q9_part_11',
 'q9_other',
 'q10_part_1',
 'q10_part_2',
 'q10_part_3',
 'q10_part_4',
 'q10_part_5',
 'q10_part_6',
 'q36_part_2',
 'q36_part_3',
 'q36_part_4',
 'q36_part_5',
 'q36_part_6',
 'q36_part_7',
 'q36_part_8',
 'q36_part_9',
 'q36_other',
]

# %%
part_b_dropped = [
    'q26_b_part_1',
 'q26_b_part_2',
 'q26_b_part_3',
 'q26_b_part_4',
 'q26_b_part_5',
 'q26_b_part_6',
 'q26_b_part_7',
 'q26_b_part_8',
 'q26_b_part_9',
 'q26_b_part_10',
 'q26_b_part_11',
 'q26_b_other',
 'q27_b_part_1',
 'q27_b_part_2',
 'q27_b_part_3',
 'q27_b_part_4',
 'q27_b_part_5',
 'q27_b_part_6',
 'q27_b_part_7',
 'q27_b_part_8',
 'q27_b_part_9',
 'q27_b_part_10',
 'q27_b_part_11',
 'q27_b_other',
 'q28_b_part_1',
 'q28_b_part_2',
 'q28_b_part_3',
 'q28_b_part_4',
 'q28_b_part_5',
 'q28_b_part_6',
 'q28_b_part_7',
 'q28_b_part_8',
 'q28_b_part_9',
 'q28_b_part_10',
 'q28_b_other',
 'q29_b_part_1',
 'q29_b_part_2',
 'q29_b_part_3',
 'q29_b_part_4',
 'q29_b_part_5',
 'q29_b_part_6',
 'q29_b_part_7',
 'q29_b_part_8',
 'q29_b_part_9',
 'q29_b_part_10',
 'q29_b_part_11',
 'q29_b_part_12',
 'q29_b_part_13',
 'q29_b_part_14',
 'q29_b_part_15',
 'q29_b_part_16',
 'q29_b_part_17',
 'q29_b_other',
 'q31_b_part_1',
 'q31_b_part_2',
 'q31_b_part_3',
 'q31_b_part_4',
 'q31_b_part_5',
 'q31_b_part_6',
 'q31_b_part_7',
 'q31_b_part_8',
 'q31_b_part_9',
 'q31_b_part_10',
 'q31_b_part_11',
 'q31_b_part_12',
 'q31_b_part_13',
 'q31_b_part_14',
 'q31_b_other',
 'q33_b_part_1',
 'q33_b_part_2',
 'q33_b_part_3',
 'q33_b_part_4',
 'q33_b_part_5',
 'q33_b_part_6',
 'q33_b_part_7',
 'q33_b_other',
 'q34_b_part_1',
 'q34_b_part_2',
 'q34_b_part_3',
 'q34_b_part_4',
 'q34_b_part_5',
 'q34_b_part_6',
 'q34_b_part_7',
 'q34_b_part_8',
 'q34_b_part_9',
 'q34_b_part_10',
 'q34_b_part_11',
 'q34_b_other',
 'q35_b_part_1',
 'q35_b_part_2',
 'q35_b_part_3',
 'q35_b_part_4',
 'q35_b_part_5',
 'q35_b_part_6',
 'q35_b_part_7',
 'q35_b_part_8',
 'q35_b_part_9',
 'q35_b_part_10',
 'q35_b_other'
]

# %%
salary_data = salary_data.drop(columns = one_hot_dropped)

# %%
salary_data = salary_data.drop(columns = part_b_dropped)

# %%
salary_data_selected_questions = salary_data.drop(columns = dropped_questions)

# %% [markdown]
# # DNN Model

# %%
X = salary_data_as_num.drop(columns = ["q24"])
y = salary_data_as_num["q24"]

# %%
y
# Out:
# 1        3
# 2        2
# 3        3
# 8        2
# 11       2
#         ..
# 20024    1
# 20029    2
# 20033    1
# 20034    1
# 20035    1
# Name: q24, Length: 10729, dtype: int64

# %%
# X = tf.convert_to_tensor(X.astype("int64"))
# y = tf.convert_to_tensor(y.astype("int64"))

# %%
x_dev, x_test, y_dev, y_test = train_test_split(X, y, test_size = 0.2, random_state = 6)

# %%
x_dev, x_val, y_dev, y_val = train_test_split(x_dev, y_dev, test_size = 0.2, random_state = 16)

# %%
x_dev = tf.convert_to_tensor(x_dev.astype("int64"))
y_dev = tf.convert_to_tensor(y_dev.astype("int64"))
x_test = tf.convert_to_tensor(x_test.astype("int64"))
y_test = tf.convert_to_tensor(y_test.astype("int64"))
x_val = tf.convert_to_tensor(x_val.astype("int64"))
y_val = tf.convert_to_tensor(y_val.astype("int64"))

# %%
class DNN:
    
    def __init__(self, x_dev = x_dev, y_dev = y_dev, x_test = x_test, y_test = y_test, x_val = x_val, y_val = y_val):
        self.x_dev = x_dev
        self.y_dev = y_dev
        self.x_test = x_test
        self.y_test = y_test
        self.x_val = x_val
        self.y_val = y_val
        
        self.layers = [Dense(32, input_shape = (80, ), activation = "relu")]
        
        self.optimizer = "adam"
        self.loss = "sparse_categorical_crossentropy"
        self.metrics =  ["accuracy"]
        
        self.batch_size = 100
        self.epochs = 50
        
    def customize_first_layer(self, node_count = 32):
        self.layers = [Dense(node_count, input_shape = (80, ), activation = "relu")]
        
    def add_one_dense_layer(self, node_count = 32):
        self.layers.append(Dense(node_count, activation = "relu"))
        
    def customize_middle_layers(self, layers):
        self.layers.extend(layers)
    
    def customize_compile(self,
                          optimizer = "adam",
                          loss = "sparse_categorical_crossentropy",
                          metrics = ["accuracy"]):
        self.optimizer = optimizer
        self.loss = loss
        self.metrics = metrics
    
    def customize_fit(self,
                      batch_size = 100,
                      epochs = 50
                      ):
        self.batch_size = batch_size
        self.epochs = epochs
    
    def build_compile_and_evaluate(self, metric_to_return = "accuracy", selection_criteria = max):
        # final layer must be softmax and outputs 4
        self.layers.append(Dense(4, activation = "softmax"))
        
        self.model = Sequential(self.layers)
        self.model.compile(optimizer = self.optimizer,
                      loss = self.loss,
                      metrics = self.metrics)
        fit_history = self.model.fit(self.x_dev, self.y_dev,
                                batch_size = self.batch_size,
                                epochs = self.epochs,
                                validation_data = (self.x_dev, self.y_dev),
                                verbose = 1
                                )
        self.fit_history = pd.DataFrame(fit_history.history)
        return selection_criteria(self.fit_history[metric_to_return])
    
    def get_model_summary(self):
        self.model.summary()
        
    def get_fit_history(self):
        return self.fit_history
        
    def evaluate_model_with_test(self):
        return self.model.evaluate(self.x_test, self.y_test, verbose = 0)
    
    def evaluate_model_with_roc_auc(self):
        pred_prob = self.model.predict(self.x_test)
        return roc_auc_score(y_test, pred_prob, average = "weighted", multi_class = "ovr")
    
    def compute_model_validation_roc_auc(self):
        pred_prob = self.model.predict(self.x_val)
        return roc_auc_score(y_val, pred_prob, average = "weighted", multi_class = "ovr")

# %%
d = DNN()
d.customize_fit(epochs = 2)
d.add_one_dense_layer()
d.build_compile_and_evaluate()
# Out:
# Epoch 1/2
# 69/69 [==============================] - 2s 17ms/step - loss: 2.6144 - accuracy: 0.4288 - val_loss: 1.2096 - val_accuracy: 0.4798
# Epoch 2/2
# 69/69 [==============================] - 1s 14ms/step - loss: 1.1026 - accuracy: 0.4811 - val_loss: 1.0148 - val_accuracy: 0.5009
# 0.48106613755226135

# %% [markdown]
# ## Epochs and Single Layer Width

# %%
results = []
consolidated_results = []
epochs = [10, 20, 50, 100, 200, 500]

for epoch in epochs:
    for i in range(1, 10):
        first_layer_width = 2 ** i
        print("---- building model for first layer width " + str(first_layer_width) + " for " + str(epoch) + " epochs")
        
        d = DNN()
        d.customize_first_layer(first_layer_width)
        d.customize_fit(epochs = epoch)
        
        #d.customize_fit(epochs = 1) ## TODO: REMOVE
    
        val_acc_result = d.build_compile_and_evaluate()
        test_loss, test_accuracy = d.evaluate_model_with_test()
        val_roc_auc = d.compute_model_validation_roc_auc()
        test_roc_auc = d.evaluate_model_with_roc_auc()
    
        results.append((first_layer_width, epoch, val_acc_result, "Validation Accuracy"))
        results.append((first_layer_width, epoch, test_loss, "Test Loss"))
        results.append((first_layer_width, epoch, test_accuracy, "Test Accuracy"))
        results.append((first_layer_width, epoch, val_roc_auc, "Validation ROC-AUC Score"))
        results.append((first_layer_width, epoch, test_roc_auc, "Test ROC-AUC Score"))
        
        consolidated_results.append((first_layer_width, epoch, val_acc_result, test_loss, test_accuracy, val_roc_auc, test_roc_auc))
    
results = pd.DataFrame(results)
results = results.rename(columns = {
    0: "First Layer Width", # TODO: remember to update appropriately
    1: "Epochs",
    2: "Metrics Value",
    3: "Metrics Type"
})
results
# Out:
# ---- building model for first layer width 2 for 10 epochs
# Epoch 1/10
# 69/69 [==============================] - 3s 22ms/step - loss: 1.1014 - accuracy: 0.5189 - val_loss: 1.0395 - val_accuracy: 0.5449
# Epoch 2/10
# 69/69 [==============================] - 1s 12ms/step - loss: 0.9908 - accuracy: 0.5620 - val_loss: 0.9413 - val_accuracy: 0.5786
# Epoch 3/10
# 69/69 [==============================] - 1s 15ms/step - loss: 0.9058 - accuracy: 0.5803 - val_loss: 0.8743 - val_accuracy: 0.5867
# Epoch 4/10
# 69/69 [==============================] - 1s 13ms/step - loss: 0.8575 - accuracy: 0.5951 - val_loss: 0.8440 - val_accuracy: 0.5969
# Epoch 5/10
# 69/69 [==============================] - 1s 12ms/step - loss: 0.8347 - accuracy: 0.5993 - val_loss: 0.8261 - val_accuracy: 0.6031
# Epoch 6/10
# 69/69 [==============================] - 1s 10ms/step - loss: 0.8215 - accuracy: 0.6089 - val_loss: 0.8151 - val_accuracy: 0.6136
# Epoch 7/10
# 69/69 [==============================] - 1s 10ms/step - loss: 0.8126 - accuracy: 0.6143 - val_loss: 0.8076 - val_accuracy: 0.6156
# Epoch 8/10
# 69/69 [==============================] - 1s 10ms/step - loss: 0.8057 - accuracy: 0.6186 - val_loss: 0.8013 - val_accuracy: 0.6202
# Epoch 9/10
# 69/69 [==============================] - 1s 9ms/step - loss: 0.8010 - accuracy: 0.6181 - val_loss: 0.7973 - val_accuracy: 0.6239
# Epoch 10/10
# 69/69 [==============================] - 1s 9ms/step - loss: 0.
#      First Layer Width  Epochs  Metrics Value              Metrics Type
# 0                    2      10       0.623216       Validation Accuracy
# 1                    2      10       0.810158                 Test Loss
# 2                    2      10       0.621622             Test Accuracy
# 3                    2      10       0.416170  Validation ROC-AUC Score
# 4                    2      10       0.419631        Test ROC-AUC Score
# ..                 ...     ...            ...                       ...
# 265                512     500       0.626274       Validation Accuracy
# 266                512     500       7.979325                 Test Loss
# 267                512     500       0.463653             Test Accuracy
# 268                512     500       0.478290  Validation ROC-AUC Score
# 269                512     500       0.485817        Test ROC-AUC Score
#
# [270 rows x 4 columns]

# %%
consolidated_results = pd.DataFrame(consolidated_results)
consolidated_results = consolidated_results.rename(columns = {
    0: "First Layer Width",
    1: "Epochs",
    2: "Validation Accuracy",
    3: "Test Loss",
    4: "Test Accuracy",
    5: "Validation ROC-AUC Score",
    6: "Test ROC-AUC Score"
})
consolidated_results
# Out:
#     First Layer Width  Epochs  Validation Accuracy  Test Loss  Test Accuracy  \
# 0                   2      10             0.623216   0.810158       0.621622
# 1                   4      10             0.584620   0.864691       0.570829
# 2                   8      10             0.542237   0.886380       0.536347
# 3                  16      10             0.626566   0.809941       0.617428
# 4                  32      10             0.633265   0.807302       0.604846
# 5                  64      10             0.631955   0.804450       0.616962
# 6                 128      10             0.629187   0.800404       0.617894
# 7                 256      10             0.620886   0.796293       0.619292
# 8                 512      10             0.622051   0.836010       0.587605
# 9                   2      20             0.496941   0.989604       0.495806
# 10                  4      20             0.632392   0.811371       0.605778
# 11                  8      20             0.628168   0.805923       0.610438
# 12                 16      20             0.638363   0.815574       0.614632
# 13                 32      20             0.640111   0.795080       0.624884
# 14                 64      20             0.637489   0.792028       0.618826
# 15                128      20             0.635013   0.816521       0.615564
# 16                256      20             0.629770   0.797928       0.622554
# 17                512      20             0.626420   0.923503       0.569431
# 18                  2      50             0.618701   0.826662       0.609972
# 19                  4      50             0.636033   0.802131       0.624418
# 20                  8      50             0.640985   0.791367       0.622088
# 21                 16      50             0.640111   0.805450       0.623020
# 22                 32      50             0.640256   0.795264       0.622088
# 23                 64      50             0.634285   0.797865       0.619758
# 24                128      50             0.637198   0.810243       0.620224
# 25                256      50             0.633994   0.827128       0.593197
# 26                512      50             0.624818   1.106662       0.544268
# 27                  2     100             0.638946   0.807719       0.609972
# 28                  4     100             0.642295   0.792401       0.624884
# 29                  8     100             0.642441   0.794585       0.620224
# 30                 16     100             0.643315   0.790350       0.623952
# 31                 32     100             0.640256   0.787833       0.620224
# 32                 64     100             0.638363   0.793328       0.628611
# 33                128     100             0.637926   0.798348       0.619292
# 34                256     100             0.634722   1.007292       0.547996
# 35                512     100             0.625401   1.015666       0.567102
# 36                  2     200             0.639528   0.815661       0.597390
# 37                  4     200             0.640402   0.792666       0.627679
# 38                  8     200             0.645208   0.787363       0.630475
# 39                 16     200             0.643461   0.795801       0.622088
# 40                 32     200             0.640548   0.810491       0.607176
# 41                 64     200             0.639528   0.832394       0.606244
# 42                128     200             0.636033   1.173612       0.514911
# 43                256     200             0.630061   0.859468       0.617428
# 44                512     200             0.623216   1.329940       0.561510
# 45                  2     500             0.635013   0.799871       0.618360
# 46                  4     500             0.642878   0.798854       0.618826
# 47                  8     500             0.647393   0.790799       0.625815
# 48                 16     500             0.644189   0.808622       0.622554
# 49                 32     500             0.642295   0.797818       0.609972
# 50                 64     500             0.636178   0.955640       0.527959
# 51                128     500             0.633994   1.109118       0.546598
# 52                256     500             0.630935   1.157447       0.613700
# 53                512     500             0.626274   7.979325       0.463653
#
#     Validation ROC-AUC Score  Test ROC-AUC Score
# 0                   0.416170            0.419631
# 1                   0.449298            0.459865
# 2                   0.442797            0.445154
# 3                   0.398995            0.407340
# 4                   0.408211            0.413192
# 5                   0.455762            0.458464
# 6                   0.470638            0.482325
# 7                   0.430728            0.437194
# 8                   0.454670            0.457620
# 9                   0.580754            0.586402
# 10                  0.445587            0.457288
# 11                  0.431562            0.436617
# 12                  0.493762            0.502953
# 13                  0.449394            0.458285
# 14                  0.415635            0.421887
# 15                  0.431313            0.439224
# 16                  0.491397            0.490955
# 17                  0.504463            0.506388
# 18                  0.400801            0.407662
# 19                  0.441609            0.444743
# 20                  0.512835            0.518199
# 21                  0.494571            0.502639
# 22                  0.471452            0.477538
# 23                  0.506647            0.508807
# 24                  0.520802            0.517976
# 25                  0.453513            0.459669
# 26                  0.536239            0.533794
# 27                  0.426009            0.436613
# 28                  0.390330            0.400262
# 29                  0.498281            0.504940
# 30                  0.438002            0.443829
# 31                  0.523252            0.527192
# 32                  0.409064            0.415456
# 33                  0.504300            0.506439
# 34                  0.415732            0.423557
# 35                  0.460401            0.469101
# 36                  0.510112            0.514511
# 37                  0.503894            0.514757
# 38                  0.483276            0.491847
# 39                  0.450544            0.457794
# 40                  0.490539            0.495827
# 41                  0.465504            0.472387
# 42                  0.477394            0.479527
# 43                  0.428652            0.436627
# 44                  0.427202            0.432799
# 45                  0.414049            0.421885
# 46                  0.430180            0.437677
# 47                  0.459299            0.469016
# 48                  0.485812            0.492005
# 49                  0.469524            0.457341
# 50                  0.443261            0.451185
# 51                  0.462408            0.471895
# 52                  0.445654            0.452360
# 53                  0.478290            0.485817

# %%
roc_auc_only = results[results["Metrics Type"] == "Validation ROC-AUC Score"]
roc_auc_only
# Out:
#      First Layer Width  Epochs  Metrics Value              Metrics Type
# 3                    2      10       0.416170  Validation ROC-AUC Score
# 8                    4      10       0.449298  Validation ROC-AUC Score
# 13                   8      10       0.442797  Validation ROC-AUC Score
# 18                  16      10       0.398995  Validation ROC-AUC Score
# 23                  32      10       0.408211  Validation ROC-AUC Score
# 28                  64      10       0.455762  Validation ROC-AUC Score
# 33                 128      10       0.470638  Validation ROC-AUC Score
# 38                 256      10       0.430728  Validation ROC-AUC Score
# 43                 512      10       0.454670  Validation ROC-AUC Score
# 48                   2      20       0.580754  Validation ROC-AUC Score
# 53                   4      20       0.445587  Validation ROC-AUC Score
# 58                   8      20       0.431562  Validation ROC-AUC Score
# 63                  16      20       0.493762  Validation ROC-AUC Score
# 68                  32      20       0.449394  Validation ROC-AUC Score
# 73                  64      20       0.415635  Validation ROC-AUC Score
# 78                 128      20       0.431313  Validation ROC-AUC Score
# 83                 256      20       0.491397  Validation ROC-AUC Score
# 88                 512      20       0.504463  Validation ROC-AUC Score
# 93                   2      50       0.400801  Validation ROC-AUC Score
# 98                   4      50       0.441609  Validation ROC-AUC Score
# 103                  8      50       0.512835  Validation ROC-AUC Score
# 108                 16      50       0.494571  Validation ROC-AUC Score
# 113                 32      50       0.471452  Validation ROC-AUC Score
# 118                 64      50       0.506647  Validation ROC-AUC Score
# 123                128      50       0.520802  Validation ROC-AUC Score
# 128                256      50       0.453513  Validation ROC-AUC Score
# 133                512      50       0.536239  Validation ROC-AUC Score
# 138                  2     100       0.426009  Validation ROC-AUC Score
# 143                  4     100       0.390330  Validation ROC-AUC Score
# 148                  8     100       0.498281  Validation ROC-AUC Score
# 153                 16     100       0.438002  Validation ROC-AUC Score
# 158                 32     100       0.523252  Validation ROC-AUC Score
# 163                 64     100       0.409064  Validation ROC-AUC Score
# 168                128     100       0.504300  Validation ROC-AUC Score
# 173                256     100       0.415732  Validation ROC-AUC Score
# 178                512     100       0.460401  Validation ROC-AUC Score
# 183                  2     200       0.510112  Validation ROC-AUC Score
# 188                  4     200       0.503894  Validation ROC-AUC Score
# 193                  8     200       0.483276  Validation ROC-AUC Score
# 198                 16     200       0.450544  Validation ROC-AUC Score
# 203                 32     200       0.490539  Validation ROC-AUC Score
# 208                 64     200       0.465504  Validation ROC-AUC Score
# 213                128     200       0.477394  Validation ROC-AUC Score
# 218                256     200       0.428652  Validation ROC-AUC Score
# 223                512     200       0.427202  Validation ROC-AUC Score
# 228                  2     500       0.414049  Validation ROC-AUC Score
# 233                  4     500       0.430180  Validation ROC-AUC Score
# 238                  8     500       0.459299  Validation ROC-AUC Score
# 243                 16     500       0.485812  Validation ROC-AUC Score
# 248                 32     500       0.469524  Validation ROC-AUC Score
# 253                 64     500       0.443261  Validation ROC-AUC Score
# 258                128     500       0.462408  Validation ROC-AUC Score
# 263                256     500       0.445654  Validation ROC-AUC Score
# 268                512     500       0.478290  Validation ROC-AUC Score

# %%
# find the best test ROC-AUC score in the above DF
roc_auc_only.iloc[roc_auc_only["Metrics Value"].argmax()]
# Out:
# First Layer Width                           2
# Epochs                                     20
# Metrics Value                        0.580754
# Metrics Type         Validation ROC-AUC Score
# Name: 48, dtype: object

# %%
best_val_roc_auc = roc_auc_only.iloc[roc_auc_only["Metrics Value"].argmax()]

# %%
# get entire performance from consolidated datafrae
best_row = consolidated_results[(consolidated_results["First Layer Width"] == best_val_roc_auc["First Layer Width"]) &
                     (consolidated_results["Epochs"] == best_val_roc_auc["Epochs"])]
best_row
# Out:
#    First Layer Width  Epochs  Validation Accuracy  Test Loss  Test Accuracy  \
# 9                  2      20             0.496941   0.989604       0.495806
#
#    Validation ROC-AUC Score  Test ROC-AUC Score
# 9                  0.580754            0.586402

# %%
def DNN_best_ROC_AUC_SCORE():
    return best_row["Test ROC-AUC Score"].iloc[0]

# %%
DNN_best_ROC_AUC_SCORE()
# Out:
# 0.5864016805333516
