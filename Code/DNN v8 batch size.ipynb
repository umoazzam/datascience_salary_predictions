# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten
# Out:
# /Users/jasminecjwchen/Documents/GitHub/COMS4995-AML-Project/.venv/lib/python3.9/site-packages/urllib3/__init__.py:34: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import random
import math

# %%
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.calibration import LabelEncoder
from sklearn.metrics import roc_auc_score

# %%
from scikeras.wrappers import KerasClassifier

# %%
# %matplotlib inline
sns.set_theme()

# %%
df = pd.read_csv("kaggle_survey_2020_responses.csv")

# %%
salary_data = df.drop(columns = ["time_from_start_to_finish_seconds"])

# %%
salary_data = salary_data.dropna(subset = ["q24"])

# %%
salary_data_as_num = pd.DataFrame()

# %%
def convert_to_category(col_name: str, order_rules: list, data):
    data[col_name] = pd.Categorical(data[col_name], order_rules)

# %%
def convert_to_category_no_specified_order(col_name, data):
    if sum(data[col_name].isna().astype(int)) > 0:
        data[col_name].fillna("No response", inplace = True)
    
    order = list(set(data[col_name]))
    convert_to_category(col_name, order, data)

# %%
def convert_category_to_code(col_name: str, data, inplace = False):
    if inplace:
        data[col_name] = data[col_name].cat.codes + 1 # because NaN automatically becomes -1
    else:
        return data[col_name].cat.codes + 1

# %%
def process_column(col_name: str, order_rules = None, data = salary_data, num_data = salary_data_as_num):
    if order_rules:
        convert_to_category(col_name, order_rules, data)
    else:
        convert_to_category_no_specified_order(col_name, data)
    num_data[col_name] = convert_category_to_code(col_name, data)

# %%
def one_hot_column_to_binary(col_name, data = salary_data):
    data[col_name].fillna(0, inplace = True)
    data[col_name].mask(data[col_name] != 0, 1, inplace = True)

# %%
def process_one_hot_encoded_columns(columns, data = salary_data, num_data = salary_data_as_num):
    for col in columns:
        one_hot_column_to_binary(col, data)
        num_data[col] = data[col]

# %%
def column_text_to_binary(col_name, data = salary_data, num_data = salary_data_as_num):
    data[col_name] = data[col_name].notna().astype(int)
    num_data[col_name] = data[col_name]

# %%
def combine_multiple_columns_into_one_binary(columns, new_col_name, data = salary_data, num_data = salary_data_as_num):
    for col_name in columns:
        one_hot_column_to_binary(col_name)
        
    data[new_col_name] = data[columns].sum(axis = 1)
    data[new_col_name] = data[new_col_name].astype(int)
    
    data[new_col_name].mask(data[new_col_name] > 0, 1, inplace = True)
    num_data[new_col_name] = data[new_col_name]

# %% [markdown]
# ## Q24 Target Column

# %% [markdown]
# ### v1: original bins

# %%
q24_order = ["$0-999",
             '1,000-1,999',
             '2,000-2,999',
             '3,000-3,999',
             '4,000-4,999',
             '5,000-7,499',
             '7,500-9,999',
             '10,000-14,999',
             '15,000-19,999',
             '20,000-24,999',
             '25,000-29,999',
             '30,000-39,999',
             '40,000-49,999',
             '50,000-59,999',
              '60,000-69,999',
              '70,000-79,999',
              '80,000-89,999',
              '90,000-99,999',
            '100,000-124,999',
            '125,000-149,999',
            '150,000-199,999',
             '200,000-249,999',
             '250,000-299,999',
              '300,000-500,000',
              '> $500,000'
             ]

# %% [markdown]
# ## v2: numerical

# %%
q24_mapped_to = [
    1, #"$0-999",
    1, #        '1,000-1,999',
    1, #         '2,000-2,999',
    1, #         '3,000-3,999',
    1, #         '4,000-4,999',
    1, #        '5,000-7,499',
    1, #         '7,500-9,999',
    2, #         '10,000-14,999',
    2, #         '15,000-19,999',
    2, #         '20,000-24,999',
    2, #         '25,000-29,999',
    2, #         '30,000-39,999',
    2, #         '40,000-49,999',
    2, #         '50,000-59,999',
    2, #          '60,000-69,999',
    2, #          '70,000-79,999',
    2, #          '80,000-89,999',
    2, #          '90,000-99,999',
    3, #        '100,000-124,999',
    3, #        '125,000-149,999',
    3, #        '150,000-199,999',
    3, #         '200,000-249,999',
    3, #         '250,000-299,999',
    3, #          '300,000-500,000',
    4 #          '> $500,000'
]

# %%
q24_mapping = dict(zip(q24_order, q24_mapped_to))

# %%
test_col = salary_data["q24"].copy()
test_col
# Out:
# 1        100,000-124,999
# 2          15,000-19,999
# 3        125,000-149,999
# 8          70,000-79,999
# 11         30,000-39,999
#               ...
# 20024        2,000-2,999
# 20029      15,000-19,999
# 20033             $0-999
# 20034             $0-999
# 20035             $0-999
# Name: q24, Length: 10729, dtype: object

# %%
test_col = test_col.replace(q24_mapping)

# %%
salary_data["q24"] = test_col
salary_data_as_num["q24"] = test_col

# %% [markdown]
# ## Q1 Age

# %%
salary_data["q1"].value_counts()
# Out:
# q1
# 25-29    2350
# 30-34    1979
# 35-39    1467
# 22-24    1424
# 40-44    1042
# 45-49     771
# 50-54     536
# 18-21     498
# 60-69     309
# 55-59     301
# 70         52
# Name: count, dtype: int64

# %%
q1_order = [
    "18-21",
    "22-24",
    "25-29",
    "30-34",
    "35-39",
    "40-44",
    "45-49",
    "50-54",
    "55-59",
    "60-69",
    "70"
]

# %%
convert_to_category("q1", q1_order, salary_data)

# %%
salary_data_as_num["q1"] = convert_category_to_code("q1", salary_data, False)
salary_data_as_num
# Out:
#        q24  q1
# 1        3   4
# 2        2   5
# 3        3   4
# 8        2   5
# 11       2   5
# ...    ...  ..
# 20024    1   5
# 20029    2   5
# 20033    1   4
# 20034    1   2
# 20035    1   2
#
# [10729 rows x 2 columns]

# %%
salary_data_as_num["q1"].value_counts()
# Out:
# q1
# 3     2350
# 4     1979
# 5     1467
# 2     1424
# 6     1042
# 7      771
# 8      536
# 1      498
# 10     309
# 9      301
# 11      52
# Name: count, dtype: int64

# %% [markdown]
# ## Q2 Gender

# %%
salary_data["q2"].value_counts()
# Out:
# q2
# Man                        8872
# Woman                      1683
# Prefer not to say           131
# Prefer to self-describe      23
# Nonbinary                    20
# Name: count, dtype: int64

# %%
q2_order = ['Man', "Woman", "Nonbinary", 'Prefer to self-describe', 'Prefer not to say']

# %%
convert_to_category("q2", q2_order, salary_data)

# %%
salary_data_as_num["q2"] = convert_category_to_code("q2", salary_data, False)
salary_data_as_num
# Out:
#        q24  q1  q2
# 1        3   4   1
# 2        2   5   1
# 3        3   4   1
# 8        2   5   1
# 11       2   5   1
# ...    ...  ..  ..
# 20024    1   5   1
# 20029    2   5   1
# 20033    1   4   1
# 20034    1   2   1
# 20035    1   2   1
#
# [10729 rows x 3 columns]

# %%
salary_data_as_num["q2"].value_counts()
# Out:
# q2
# 1    8872
# 2    1683
# 5     131
# 4      23
# 3      20
# Name: count, dtype: int64

# %% [markdown]
# ## Q3 Country

# %%
convert_to_category_no_specified_order("q3", salary_data)

# %%
salary_data_as_num["q3"] = convert_category_to_code("q3", salary_data)

# %% [markdown]
# ## Q4 Education

# %%
salary_data["q4"].value_counts()
# Out:
# q4
# Master’s degree                                                      4879
# Bachelor’s degree                                                    3013
# Doctoral degree                                                      1718
# Professional degree                                                   470
# Some college/university study without earning a bachelor’s degree     385
# I prefer not to answer                                                158
# No formal education past high school                                  106
# Name: count, dtype: int64

# %%
q4_order = ["No formal education past high school",
            "Some college/university study without earning a bachelor’s degree",
            "Professional degree",
            "Bachelor’s degree",
            "Master’s degree",
            "Doctoral degree",
            "I prefer not to answer"
            ]

# %%
convert_to_category("q4", q4_order, salary_data)

# %%
salary_data_as_num["q4"] = convert_category_to_code("q4", salary_data)

# %%
salary_data_as_num["q4"].value_counts()
# Out:
# q4
# 5    4879
# 4    3013
# 6    1718
# 3     470
# 2     385
# 7     158
# 1     106
# Name: count, dtype: int64

# %% [markdown]
# ## Q5 Job Title

# %%
salary_data["q5"].value_counts()
# Out:
# q5
# Data Scientist               2398
# Software Engineer            1620
# Other                        1508
# Data Analyst                 1260
# Research Scientist           1028
# Machine Learning Engineer     918
# Business Analyst              678
# Product/Project Manager       590
# Data Engineer                 369
# Statistician                  248
# DBA/Database Engineer         112
# Name: count, dtype: int64

# %%
convert_to_category_no_specified_order("q5", salary_data)

# %%
salary_data_as_num["q5"] = convert_category_to_code("q5", salary_data)

# %% [markdown]
# ## Q6 Years Coding

# %%
q6_order = [
 'I have never written code',
 '< 1 years',
 '1-2 years',
 '3-5 years',
 '5-10 years',
 '10-20 years',
 '20+ years']

# %%
process_column("q6", q6_order)

# %% [markdown]
# ## Q7 Language

# %%
q7_columns = [
     'q7_part_1',
 'q7_part_2',
 'q7_part_3',
 'q7_part_4',
 'q7_part_5',
 'q7_part_6',
 'q7_part_7',
 'q7_part_8',
 'q7_part_9',
 'q7_part_10',
 'q7_part_11',
 'q7_part_12',
 'q7_other'
]

# %%
process_one_hot_encoded_columns(q7_columns)

# %% [markdown]
# ## Q11 Computing Platform

# %%
process_column("q11")

# %% [markdown]
# ## Q12 Specialized Hardware

# %%
q12_columns = [
    'q12_part_1',
 'q12_part_2',
 'q12_part_3',
 'q12_other'
]

# %%
process_one_hot_encoded_columns(q12_columns)

# %% [markdown]
# ## Q14 Visualization

# %%
q14_columns = [
    'q14_part_1',
 'q14_part_2',
 'q14_part_3',
 'q14_part_4',
 'q14_part_5',
 'q14_part_6',
 'q14_part_7',
 'q14_part_8',
 'q14_part_9',
 'q14_part_10',
 'q14_part_11',
 'q14_other'
]

# %%
process_one_hot_encoded_columns(q14_columns)

# %% [markdown]
# ## Q15 Years ML

# %%
q15_order = [
    'I do not use machine learning methods',
    'Under 1 year',
    '1-2 years',
    '2-3 years',
    '3-4 years',
    '4-5 years',
    '5-10 years',
    '10-20 years',
    '20 or more years'
]

# %%
process_column("q15", q15_order)

# %% [markdown]
# ## Q17 ML Algorithms

# %%
q17_columns = [
    'q17_part_1',
 'q17_part_2',
 'q17_part_3',
 'q17_part_4',
 'q17_part_5',
 'q17_part_6',
 'q17_part_7',
 'q17_part_8',
 'q17_part_9',
 'q17_part_10',
 'q17_part_11',
 'q17_other'
]

# %%
process_one_hot_encoded_columns(q17_columns)

# %% [markdown]
# ## Q20 Company Size

# %%
q20_order = [
    '0-49 employees',
    '50-249 employees',
    '250-999 employees',
    '1000-9,999 employees',
    '10,000 or more employees'
]

# %%
process_column("q20", q20_order)

# %% [markdown]
# ## Q21 Datascience Workloads

# %%
q21_order = [
    '0',
    '1-2',
    '3-4',
    '5-9',
    '10-14',
    '15-19',
    '20'
]

# %%
process_column("q21", q21_order)

# %% [markdown]
# ## Q22 Incorporating ML

# %% [markdown]
# i'm not super sure about the proper "order" for this question. Feel free to change this if you find it more appropriate. Just please let the chat know in case it affects others' encoding.

# %%
q22_order = [
    'I do not know',
    'No (we do not use ML methods)',
    'We are exploring ML methods (and may one day put a model into production)',
    'We use ML methods for generating insights (but do not put working models into production)',
    'We recently started using ML methods (i.e., models in production for less than 2 years)',
    'We have well established ML methods (i.e., models in production for more than 2 years)'
]

# %%
process_column("q22", q22_order)

# %% [markdown]
# ## Q30 Big Data Products

# %%
column_text_to_binary("q30")

# %% [markdown]
# ## Q32 Business Intelligence Tools

# %%
column_text_to_binary("q32")

# %% [markdown]
# ## Q33 Automated ML Tools

# %%
q33_columns = [
    'q33_a_part_1',
 'q33_a_part_2',
 'q33_a_part_3',
 'q33_a_part_4',
 'q33_a_part_5',
 'q33_a_part_6',
 'q33_a_part_7',
 'q33_a_other'
]

# %%
combine_multiple_columns_into_one_binary(q33_columns, "q33")

# %% [markdown]
# ## Q37 Data Science Courses

# %%
q37_columns = [
    'q37_part_1',
 'q37_part_2',
 'q37_part_3',
 'q37_part_4',
 'q37_part_5',
 'q37_part_6',
 'q37_part_7',
 'q37_part_8',
 'q37_part_9',
 'q37_part_10',
 'q37_part_11',
 'q37_other'
]

# %%
process_one_hot_encoded_columns(q37_columns)

# %% [markdown]
# ## Q38 Primary Data Analysis Tool

# %%
process_column("q38")

# %% [markdown]
# ## Q39 Media Sources

# %%
q39_columns = [
    'q39_part_1',
 'q39_part_2',
 'q39_part_3',
 'q39_part_4',
 'q39_part_5',
 'q39_part_6',
 'q39_part_7',
 'q39_part_8',
 'q39_part_9',
 'q39_part_10',
 'q39_part_11',
 'q39_other'
]

# %%
process_one_hot_encoded_columns(q39_columns)

# %% [markdown]
# ## Dropped Columns

# %%
one_hot_dropped = [
    'q33_a_part_1',
 'q33_a_part_2',
 'q33_a_part_3',
 'q33_a_part_4',
 'q33_a_part_5',
 'q33_a_part_6',
 'q33_a_part_7',
 'q33_a_other',
]

# %%
dropped_questions = [
    "q8",
    'q9_part_1',
 'q9_part_2',
 'q9_part_3',
 'q9_part_4',
 'q9_part_5',
 'q9_part_6',
 'q9_part_7',
 'q9_part_8',
 'q9_part_9',
 'q9_part_10',
 'q9_part_11',
 'q9_other',
 'q10_part_1',
 'q35_a_part_8',
 'q35_a_part_9',
 'q35_a_part_10',
 'q35_a_other',
 'q36_part_1',
 'q36_part_2',
 'q36_part_3',
 'q36_part_4',
 'q36_part_5',
 'q36_part_6',
 'q36_part_7',
 'q36_part_8',
 'q36_part_9',
 'q36_other',
]

# %%
part_b_dropped = [
    'q26_b_part_1',
 'q26_b_part_2',
 'q26_b_part_3',
 'q26_b_part_4',
 'q26_b_part_5',
 'q26_b_part_6',
 'q26_b_part_7',
 'q26_b_part_8',
 'q26_b_part_9',
 'q26_b_part_10',
 'q26_b_part_11',
 'q26_b_other',
 'q27_b_part_1',
 'q27_b_part_2',
 'q27_b_part_3',
 'q27_b_part_4',
 'q27_b_part_5',
 'q27_b_part_6',
 'q27_b_part_7',
 'q27_b_part_8',
 'q27_b_part_9',
 'q27_b_part_10',
 'q27_b_part_11',
 'q27_b_other',
 'q28_b_part_1',
 'q28_b_part_2',
 'q28_b_part_3',
 'q28_b_part_4',
 'q28_b_part_5',
 'q28_b_part_6',
 'q28_b_part_7',
 'q28_b_part_8',
 'q28_b_part_9',
 'q28_b_part_10',
 'q28_b_other',
 'q29_b_part_1',
 'q29_b_part_2',
 'q29_b_part_3',
 'q29_b_part_4',
 'q29_b_part_5',
 'q29_b_part_6',
 'q29_b_part_7',
 'q29_b_part_8',
 'q29_b_part_9',
 'q29_b_part_10',
 'q29_b_part_11',
 'q29_b_part_12',
 'q29_b_part_13',
 'q29_b_part_14',
 'q29_b_part_15',
 'q29_b_part_16',
 'q29_b_part_17',
 'q29_b_other',
 'q31_b_part_1',
 'q31_b_part_2',
 'q31_b_part_3',
 'q31_b_part_4',
 'q31_b_part_5',
 'q31_b_part_6',
 'q31_b_part_7',
 'q31_b_part_8',
 'q31_b_part_9',
 'q31_b_part_10',
 'q31_b_part_11',
 'q31_b_part_12',
 'q31_b_part_13',
 'q31_b_part_14',
 'q31_b_other',
 'q33_b_part_1',
 'q33_b_part_2',
 'q33_b_part_3',
 'q33_b_part_4',
 'q33_b_part_5',
 'q33_b_part_6',
 'q33_b_part_7',
 'q33_b_other',
 'q34_b_part_1',
 'q34_b_part_2',
 'q34_b_part_3',
 'q34_b_part_4',
 'q34_b_part_5',
 'q34_b_part_6',
 'q34_b_part_7',
 'q34_b_part_8',
 'q34_b_part_9',
 'q34_b_part_10',
 'q34_b_part_11',
 'q34_b_other',
 'q35_b_part_1',
 'q35_b_part_2',
 'q35_b_part_3',
 'q35_b_part_4',
 'q35_b_part_5',
 'q35_b_part_6',
 'q35_b_part_7',
 'q35_b_part_8',
 'q35_b_part_9',
 'q35_b_part_10',
 'q35_b_other'
]

# %%
salary_data = salary_data.drop(columns = one_hot_dropped)

# %%
salary_data = salary_data.drop(columns = part_b_dropped)

# %%
salary_data_selected_questions = salary_data.drop(columns = dropped_questions)

# %% [markdown]
# # DNN Model

# %%
X = salary_data_as_num.drop(columns = ["q24"])
y = salary_data_as_num["q24"]

# %%
y
# Out:
# 1        3
# 2        2
# 3        3
# 8        2
# 11       2
#         ..
# 20024    1
# 20029    2
# 20033    1
# 20034    1
# 20035    1
# Name: q24, Length: 10729, dtype: int64

# %%
x_dev, x_test, y_dev, y_test = train_test_split(X, y, test_size = 0.2, random_state = 6)

# %%
x_dev = tf.convert_to_tensor(x_dev.astype("int64"))
x_test = tf.convert_to_tensor(x_test.astype("int64"))
y_dev = tf.convert_to_tensor(y_dev.astype("int64"))
y_test = tf.convert_to_tensor(y_test.astype("int64"))
# Out:
# 2023-12-09 01:01:13.757856: I metal_plugin/src/device/metal_device.cc:1154] Metal device set to: Apple M1
# 2023-12-09 01:01:13.757888: I metal_plugin/src/device/metal_device.cc:296] systemMemory: 8.00 GB
# 2023-12-09 01:01:13.757900: I metal_plugin/src/device/metal_device.cc:313] maxCacheSize: 2.67 GB
# 2023-12-09 01:01:13.758380: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2023-12-09 01:01:13.758769: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)

# %%
class DNN:
    
    def __init__(self, x_dev = x_dev, y_dev = y_dev, x_test = x_test, y_test = y_test):
        self.x_dev = x_dev
        self.y_dev = y_dev
        self.x_test = x_test
        self.y_test = y_test
        
        self.layers = [Dense(32, input_shape = (80, ), activation = "relu")]
        
        self.optimizer = "adam"
        self.loss = "sparse_categorical_crossentropy"
        self.metrics =  ["accuracy"]
        
        self.batch_size = 100
        self.epochs = 50
        
    def customize_first_layer(self, node_count = 32):
        self.layers = [Dense(node_count, input_shape = (80, ), activation = "relu")]
        
    def add_one_dense_layer(self, node_count = 32):
        self.layers.append(Dense(node_count, activation = "relu"))
        
    def customize_middle_layers(self, layers):
        self.layers.extend(layers)
    
    def customize_compile(self,
                          optimizer = "adam",
                          loss = "sparse_categorical_crossentropy",
                          metrics = ["accuracy"]):
        self.optimizer = optimizer
        self.loss = loss
        self.metrics = metrics
    
    def customize_fit(self,
                      batch_size = 100,
                      epochs = 50
                      ):
        self.batch_size = batch_size
        self.epochs = epochs
    
    def build_compile_and_evaluate(self, metric_to_return = "accuracy", selection_criteria = max):
        # final layer must be softmax and outputs 4
        self.layers.append(Dense(4, activation = "softmax"))
        
        self.model = Sequential(self.layers)
        self.model.compile(optimizer = self.optimizer,
                      loss = self.loss,
                      metrics = self.metrics)
        fit_history = self.model.fit(self.x_dev, self.y_dev,
                                batch_size = self.batch_size,
                                epochs = self.epochs,
                                validation_split = 0.2,
                                verbose = 1
                                )
        self.fit_history = pd.DataFrame(fit_history.history)
        return selection_criteria(self.fit_history[metric_to_return])
    
    def get_model_summary(self):
        self.model.summary()
        
    def get_fit_history(self):
        return self.fit_history
        
    def evaluate_model_with_test(self):
        return self.model.evaluate(self.x_test, self.y_test, verbose = 0)
    
    def evaluate_model_with_roc_auc(self):
        pred_prob = self.model.predict(self.x_test)
        return roc_auc_score(y_test, pred_prob, average = "weighted", multi_class = "ovr")

# %%
d = DNN()
d.customize_fit(epochs = 2)
d.add_one_dense_layer()
d.build_compile_and_evaluate()
# Out:
# Epoch 1/2
# 2023-12-09 01:01:14.394672: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:117] Plugin optimizer for device_type GPU is enabled.
# 69/69 [==============================] - 1s 12ms/step - loss: 1.3710 - accuracy: 0.3986 - val_loss: 1.0111 - val_accuracy: 0.4700
# Epoch 2/2
# 25/69 [=========>....................] - ETA: 0s - loss: 0.9836 - accuracy: 0.4904
# 69/69 [==============================] - 1s 9ms/step - loss: 0.9415 - accuracy: 0.5189 - val_loss: 0.8876 - val_accuracy: 0.5545
# 0.518933892250061

# %% [markdown]
# ## Batch Size

# %%
results = []

# %%
baseline_d = DNN()
baseline_d.customize_first_layer(2)
baseline_d.customize_fit(batch_size = 1)
baseline_val_acc = baseline_d.build_compile_and_evaluate()
baseline_test_loss, baseline_test_acc = baseline_d.evaluate_model_with_test()
baseline_roc_auc = baseline_d.evaluate_model_with_roc_auc()
results.append((1, baseline_val_acc, "Validation Accuracy"))
results.append((1, baseline_test_loss, "Test Loss"))
results.append((1, baseline_test_acc, "Test Accuracy"))
results.append((1, baseline_roc_auc, "Test ROC-AUC Score"))
# Out:
# Epoch 1/50
# 6866/6866 [==============================] - 39s 5ms/step - loss: 1.0794 - accuracy: 0.4787 - val_loss: 0.9385 - val_accuracy: 0.5585
# Epoch 2/50
# 6866/6866 [==============================] - 37s 5ms/step - loss: 0.8861 - accuracy: 0.5832 - val_loss: 0.8230 - val_accuracy: 0.6092
# Epoch 3/50
# 6866/6866 [==============================] - 36s 5ms/step - loss: 0.8179 - accuracy: 0.6171 - val_loss: 0.8056 - val_accuracy: 0.6214
# Epoch 4/50
# 6866/6866 [==============================] - 37s 5ms/step - loss: 0.8044 - accuracy: 0.6232 - val_loss: 0.7881 - val_accuracy: 0.6185
# Epoch 5/50
# 6866/6866 [==============================] - 37s 5ms/step - loss: 0.8010 - accuracy: 0.6280 - val_loss: 0.7926 - val_accuracy: 0.6063
# Epoch 6/50
# 6866/6866 [==============================] - 37s 5ms/step - loss: 0.7994 - accuracy: 0.6229 - val_loss: 0.7910 - val_accuracy: 0.6226
# Epoch 7/50
# 6866/6866 [==============================] - 37s 5ms/step - loss: 0.7985 - accuracy: 0.6276 - val_loss: 0.8381 - val_accuracy: 0.5754
# Epoch 8/50
# 6866/6866 [==============================] - 37s 5ms/step - loss: 0.7990 - accuracy: 0.6225 - val_loss: 0.7896 - val_accuracy: 0.6156
# Epoch 9/50
# 6866/6866 [==============================] - 37s 5ms/step - loss: 0.7985 - accuracy: 0.6255 - val_loss: 0.7955 - val_accuracy: 0.6191
# Epoch 10/50
# 6866/6866 [==============================] - 37s 5ms/step - loss: 0.8020 - accuracy: 0.6206 - val_loss: 0.7854 - val_accuracy: 0.6209
# Epoch 11/50
# 6866/6866 [==============================] - 37s 5ms/step - loss: 0.8070 - accuracy: 0.6156 - val_loss: 0.7873 - val_accuracy: 0.6191
# Epoch 12/50
# 6866/6866 [==============================] - 37s 5ms/step - loss: 0.8130 - accuracy: 0.6149 - val_loss: 0.8024 - val_accuracy: 0.6278
# Epoch 13/50
# 6866/6866 [==============================] - 37s 5ms/step - loss: 0.8222 - accuracy: 0.6062 - val_loss: 0.7962 - val_accuracy: 0.6220
# Epoch 14/50
# 6866/6866 [==============================] - 38s 5ms/step - loss: 0.8249 - accuracy: 0.6053 - val_loss: 0.7936 - val_accuracy: 0.6098
# Epoch 15/50
# 6866/6866 [==============================] - 36s 5ms/step - loss: 0.8339 - accuracy: 0.6056 - val_loss: 0.7934 - val_accuracy: 0.6243
# Epoch 35/50
# 6866/6866 [==============================] - 36s 5ms/step - loss: 0.9695 - accuracy: 0.5564 - val_loss: 0.8164 - val_accuracy: 0.5824
# Epoch 36/50
# 6866/6866 [==============================] - 35s 5ms/step - loss: 0.9767 - accuracy: 0.5623 - val_loss: 0.9578 - val_accuracy: 0.5585
# Epoch 37/50
# 6866/6866 [==============================] - 35s 5ms/step - loss: 0.9756 - accuracy: 0.5650 - val_loss: 1.1173 - val_accuracy: 0.4648
# Epoch 38/50
# 6866/6866 [==============================] - 35s 5ms/step - loss: 0.9875 - accuracy: 0.5580 - val_loss: 0.8739 - val_accuracy: 0.5836
# Epoch 39/50
# 6866/6866 [==============================] - 35s 5ms/step - loss: 1.0016 - accuracy: 0.5502 - val_loss: 1.0244 - val_accuracy: 0.5329
# Epoch 40/50
# 6866/6866 [==============================] - 35s 5ms/step - loss: 0.9991 - accuracy: 0.5572 - val_loss: 0.8868 - val_accuracy: 0.6144
# Epoch 41/50
# 6866/6866 [==============================] - 38s 5ms/step - loss: 1.0255 - accuracy: 0.5492 - val_loss: 0.8210 - val_accuracy: 0.6220
# Epoch 42/50
# 6866/6866 [==============================] - 35s 5ms/step - loss: 1.0227 - accuracy: 0.5577 - val_loss: 1.0791 - val_accuracy: 0.5609
# Epoch 43/50
# 6866/6866 [==============================] - 36s 5ms/step - loss: 1.0186 - accuracy: 0.5577 - val_loss: 1.0380 - val_accuracy: 0.5492
# Epoch 44/50
# 6866/6866 [==============================] - 35s 5ms/step - loss: 1.0381 - accuracy: 0.5559 - val_loss: 0.8336 - val_accuracy: 0.6273
# Epoch 45/50
# 6866/6866 [==============================] - 35s 5ms/step - loss: 1.0365 - accuracy: 0.5530 - val_loss: 1.2970 - val_accuracy: 0.5044
# Epoch 46/50
# 6866/6866 [==============================] - 35s 5ms/step - loss: 1.0460 - accuracy: 0.5581 - val_loss: 0.9105 - val_accuracy: 0.5242
# Epoch 47/50
# 6866/6866 [==============================] - 35s 5ms/step - loss: 1.0582 - accuracy: 0.5571 - val_loss: 0.9996 - val_accuracy: 0.5719
# Epoch 48/50
# 6866/6866 [==============================] - 35s 5ms/step - loss: 1.0652 - accuracy: 0.5479 - val_loss: 0.8453 - val_accuracy: 0.5609
# Epoch 49/50
# 6866/6866 [==============================] - 35s 5ms/step - loss: 1.0661 - accuracy: 0.5500 - val_loss: 0.8224 - val_accuracy: 0.6075
# Epoch 50/50
# 6866/6866 [==============================] - 35s 5ms/step - loss: 1.0788 - accuracy: 0.5488 - val_loss: 0.9713 - val_accuracy: 0.4846
# 68/68 [==============================] - 0s 2ms/step

# %%
batch_results = []
for i in range(1, 21):
    batch_size = i * 50
    print("---- building model for batch size of " + str(batch_size))
    d = DNN()
    d.customize_first_layer(2)
    d.customize_fit(batch_size = batch_size)
    
    #d.customize_fit(epochs = 1) ## TODO: REMOVE
    
    val_acc_result = d.build_compile_and_evaluate()
    test_loss, test_accuracy = d.evaluate_model_with_test()
    test_roc_auc = d.evaluate_model_with_roc_auc()
    
    batch_results.append((batch_size, val_acc_result, "Validation Accuracy"))
    batch_results.append((batch_size, test_loss, "Test Loss"))
    batch_results.append((batch_size, test_accuracy, "Test Accuracy"))
    batch_results.append((batch_size, test_roc_auc, "Test ROC-AUC Score"))
    
batch_results = pd.DataFrame(results)
batch_results = batch_results.rename(columns = {
    0: "Batch Size", # TODO: remember to update appropriately
    1: "Metrics Value",
    2: "Metrics Type"
})
batch_results
# Out:
# ---- building model for batch size of 50
# Epoch 1/50
# 138/138 [==============================] - 2s 12ms/step - loss: 2.9810 - accuracy: 0.1864 - val_loss: 2.4710 - val_accuracy: 0.2632
# Epoch 2/50
# 138/138 [==============================] - 1s 8ms/step - loss: 1.8380 - accuracy: 0.2909 - val_loss: 1.3897 - val_accuracy: 0.2947
# Epoch 3/50
# 138/138 [==============================] - 1s 7ms/step - loss: 1.2510 - accuracy: 0.3844 - val_loss: 1.2098 - val_accuracy: 0.3960
# Epoch 4/50
# 138/138 [==============================] - 1s 6ms/step - loss: 1.1585 - accuracy: 0.4029 - val_loss: 1.1496 - val_accuracy: 0.3902
# Epoch 5/50
# 138/138 [==============================] - 1s 7ms/step - loss: 1.1250 - accuracy: 0.4010 - val_loss: 1.1200 - val_accuracy: 0.4007
# Epoch 6/50
# 138/138 [==============================] - 1s 6ms/step - loss: 1.1010 - accuracy: 0.4056 - val_loss: 1.0961 - val_accuracy: 0.4094
# Epoch 7/50
# 138/138 [==============================] - 1s 7ms/step - loss: 1.0812 - accuracy: 0.4069 - val_loss: 1.0759 - val_accuracy: 0.4036
# Epoch 8/50
# 138/138 [==============================] - 1s 6ms/step - loss: 1.0667 - accuracy: 0.4094 - val_loss: 1.0606 - val_accuracy: 0.4071
# Epoch 9/50
# 138/138 [==============================] - 1s 6ms/step - loss: 1.0487 - accuracy: 0.4136 - val_loss: 1.0472 - val_accuracy: 0.4054
# Epoch 10/50
# 138/138 [==============================] - 1s 6ms/step - loss: 1.0365 - accuracy: 0.4180 - val_loss: 1.0345 - val_accuracy: 0.4089
# Epoch 11/50
# 138/138 [==============================] - 1s 6ms/step - loss: 1.0251 - accuracy: 0.4189 - val_loss: 1.0223 - val_accuracy: 0.4059
# Epoch 12/50
# 138/138 [==============================] - 1s 6ms/step - loss: 1.0155 - accuracy: 0.4211 - val_loss: 1.0117 - val_accuracy: 0.4222
# Epoch 13/50
# 138/138 [==============================] - 1s 7ms/step - loss: 1.0074 - accuracy: 0.4263 - val_loss: 1.0017 - val_accuracy: 0.4263
# Epoch 14/50
# 138/138 [==============================] - 1s 6ms/step - loss: 0.9996 - accuracy: 0.4286 - val_loss: 0.9900 - val_accuracy: 0.4345
# Epoch 15/50
# 138/138 [==============================] - 1s 6ms/step - loss: 0.9839 - accuracy: 0.4457 - val_loss: 0.9668 - val_accuracy: 0.4595
# Epoch 16/50
# 138/138 [==============================] - 1s 6ms/step - loss: 0.9800 - accuracy: 0.4863 - val_loss: 0.9665 - val_accuracy: 0.4875
# Epoch 17/50
# 138/138 [==============================] - 1s 6ms/step - loss: 0.9148 - accuracy: 0.5377 - val_loss: 0.9162 - val_accuracy: 0.4974
# Epoch 37/50
# 138/138 [==============================] - 1s 7ms/step - loss: 0.9138 - accuracy: 0.5382 - val_loss: 0.9072 - val_accuracy: 0.5317
# Epoch 38/50
# 138/138 [==============================] - 1s 9ms/step - loss: 0.9121 - accuracy: 0.5386 - val_loss: 0.9056 - val_accuracy: 0.5259
# Epoch 39/50
# 138/138 [==============================] - 1s 7ms/step - loss: 0.9110 - accuracy: 0.5414 - val_loss: 0.9122 - val_accuracy: 0.5015
# Epoch 40/50
# 138/138 [==============================] - 1s 7ms/step - loss: 0.9101 - accuracy: 0.5399 - val_loss: 0.9053 - val_accuracy: 0.5294
# Epoch 41/50
# 138/138 [==============================] - 1s 6ms/step - loss: 0.9091 - accuracy: 0.5472 - val_loss: 0.9030 - val_accuracy: 0.5282
# Epoch 42/50
# 138/138 [==============================] - 1s 7ms/step - loss: 0.9098 - accuracy: 0.5438 - val_loss: 0.9029 - val_accuracy: 0.5271
# Epoch 43/50
# 138/138 [==============================] - 1s 6ms/step - loss: 0.9092 - accuracy: 0.5440 - val_loss: 0.9018 - val_accuracy: 0.5323
# Epoch 44/50
# 138/138 [==============================] - 1s 7ms/step - loss: 0.9076 - accuracy: 0.5492 - val_loss: 0.9052 - val_accuracy: 0.5218
# Epoch 45/50
# 138/138 [==============================] - 1s 6ms/step - loss: 0.9066 - accuracy: 0.5452 - val_loss: 0.9024 - val_accuracy: 0.5405
# Epoch 46/50
# 138/138 [==============================] - 1s 6ms/step - loss: 0.9062 - accuracy: 0.5532 - val_loss: 0.9041 - val_accuracy: 0.5131
# Epoch 47/50
# 138/138 [==============================] - 1s 7ms/step - loss: 0.9066 - accuracy: 0.5463 - val_loss: 0.9006 - val_accuracy: 0.5306
# Epoch 48/50
# 138/138 [==============================] - 1s 6ms/step - loss: 0.9051 - accuracy: 0.5489 - val_loss: 0.8999 - val_accuracy: 0.5253
# Epoch 49/50
# 138/138 [==============================] - 1s 6ms/step - loss: 0.9063 - accuracy: 0.5392 - val_loss: 0.8984 - val_accuracy: 0.5446
# Epoch 50/50
# 138/138 [==============================] - 1s 6ms/step - loss: 0.9032 - accuracy: 0.5548 - val_loss: 0.8990 - val_accuracy: 0.5451
# 68/68 [==============================] - 0s 2ms/step
# ---- building model for batch size of 100
# Epoch 1/50
# 69/69 [==============================] - 1s 10ms/step - loss: 1.6980 - accuracy: 0.4509 - val_loss: 1.5144 - val_accuracy: 0.4642
# Epoch 2/50
# 69/69 [==============================] - 0s 7ms/step - loss: 1.4958 - accuracy: 0.4602 - val_loss: 1.4017 - val_accuracy: 0.4537
# Epoch 3/50
# 69/69 [==============================] - 0s 7ms/step - loss: 1.
# 69/69 [==============================] - 0s 7ms/step - loss: 0.8070 - accuracy: 0.6188 - val_loss: 0.8011 - val_accuracy: 0.6197
# Epoch 45/50
# 69/69 [==============================] - 0s 7ms/step - loss: 0.8062 - accuracy: 0.6190 - val_loss: 0.8007 - val_accuracy: 0.6133
# Epoch 46/50
# 69/69 [==============================] - 0s 7ms/step - loss: 0.8060 - accuracy: 0.6193 - val_loss: 0.8009 - val_accuracy: 0.6127
# Epoch 47/50
# 69/69 [==============================] - 0s 6ms/step - loss: 0.8056 - accuracy: 0.6221 - val_loss: 0.7998 - val_accuracy: 0.6197
# Epoch 48/50
# 69/69 [==============================] - 1s 8ms/step - loss: 0.8051 - accuracy: 0.6225 - val_loss: 0.7998 - val_accuracy: 0.6220
# Epoch 49/50
# 69/69 [==============================] - 0s 7ms/step - loss: 0.8049 - accuracy: 0.6203 - val_loss: 0.7998 - val_accuracy: 0.6226
# Epoch 50/50
# 69/69 [==============================] - 0s 7ms/step - loss: 0.8050 - accuracy: 0.6206 - val_loss: 0.7995 - val_accuracy: 0.6179
# 68/68 [==============================] - 1s 2ms/step
# ---- building model for batch size of 150
# Epoch 1/50
# 46/46 [==============================] - 1s 12ms/step - loss: 1.4697 - accuracy: 0.4444 - val_loss: 1.2093 - val_accuracy: 0.4502
# Epoch 2/50
# 46/46 [==============================] - 0s 7ms/step - loss: 1.1650 - accuracy: 0.4525 - val_loss: 1.1036 - val_accuracy: 0.4723
# Epoch 3/50
# 46/46 [==============================] - 0s 7ms/step - loss: 1.0842 - accuracy: 0.4736 - val_loss: 1.0416 - val_accuracy: 0.4956
# Epoch 4/50
# 46/46 [==============================] - 0s 7ms/step - loss: 1.0342 - accuracy: 0.4987 - val_loss: 1.0064 - val_accuracy: 0.5102
# Epoch 5/50
# 46/46 [==============================] - 0s 8ms/step - loss: 1.0035 - accuracy: 0.5135 - val_loss: 0.9833 - val_accuracy: 0.5248
# Epoch 6/50
# 46/46 [==============================] - 0s 7ms/step - loss: 0.9829 - accuracy: 0.5312 - val_loss: 0.9671 - val_accuracy: 0.5416
# Epoch 7/50
# 46/46 [==============================] - 0s 7ms/step - loss: 0.9670 - accuracy: 0.5412 - val_loss: 0.9547 - val_accuracy: 0.5585
# Epoch 8/50
# 46/46 [==============================] - 0s 7ms/step - loss: 0.9546 - accuracy: 0.5527 - val_loss: 0.9451 - val_accuracy: 0.5661
# Epoch 9/50
# 46/46 [==============================] - 0s 7ms/step - loss: 0.9441 - accuracy: 0.5578 - val_loss: 0.9355 - val_accuracy: 0.5743
# Epoch 10/50
# 46/46 [==============================] - 0s 7ms/step - loss: 0.9347 - accuracy: 0.5703 - val_loss: 0.9272 - val_accuracy: 0.5789
# Epoch 11/50
# 46/46 [==============================] - 0s 7ms/step - loss: 0.9262 - accuracy: 0.5779 - val_loss: 0.9193 - val_accuracy: 0.5859
# Epoch 12/50
# 46/46 [==============================] - 0s 7ms/step - loss: 0.9179 - accuracy: 0.5803 - val_loss: 0.9113 - val_accuracy: 0.5882
# Epoch 13/50
# 46/46 [==============================] - 0s 7ms/step - loss: 0.9093 - accuracy: 0.5805 - val_loss: 0.9040 - val_accuracy: 0.5923
# Epoch 14/50
# 46/46 [==============================] - 0s 7ms/step - loss: 0.9019 - accuracy: 0.5858 - val_loss: 0.8966 - val_accuracy: 0.5923
# Epoch 15/50
# 46/46 [==============================] - 0s 7ms/step - loss: 0.8947 - accuracy: 0.5913 - val_loss: 0.8894 - val_accuracy: 0.5946
# Epoch 16/50
# 46/46 [==============================] - 0s 7ms/step - loss: 0.8870 - accuracy: 0.5935 - val_loss: 0.8837 - val_accuracy: 0.5911
# Epoch 17/50
# 46/46 [==============================] - 0s 7ms/step - loss: 0.8803 - accuracy: 0.5969 - val_loss: 0.8756 - val_accuracy: 0.6005
# Epoch 18/50
# 46/46 [==============================] - 0s 7ms/step - loss: 0.8730 - accuracy: 0.5976 - val_loss: 0.8691 - val_accuracy: 0.5981
# Epoch 19/50
# 46/46 [==============================] - 0s 7ms/step - loss: 0.8671 - accuracy: 0.5990 - val_loss: 0.8630 - val_accuracy: 0.5976
# Epoch 20/50
# 46/46 [==============================] - 0s 7ms/step - loss: 0.8604 - accuracy: 0.6012 - val_loss: 0.8551 - val_accuracy: 0.6063
# Epoch 21/50
# 46/46 [==============================] - 0s 9ms/step - loss: 0.8534 - accuracy: 0.6033 - val_loss: 0.8492 - val_accuracy: 0.6063
# Epoch 22/50
# 46/46 [==============================] - 0s 7ms/step - loss: 0.8471 - accuracy: 0.6046 - val_loss: 0.8431 - val_accuracy: 0.6104
# Epoch 23/50
# 46/46 [==============================] - 0s 9ms/step - loss: 0.8417 - accuracy: 0.6046 - val_loss: 0.8372 - val_accuracy: 0.6057
# Epoch 24/50
# 46/46 [==============================] - 0s 7ms/step - loss: 0.8369 - accuracy: 0.6072 - val_loss: 0.8339 - val_accuracy: 0.5970
# Epoch 25/50
# 46/46 [==============================] - 0s 7ms/step - loss: 0.8330 - accuracy: 0.6030 - val_loss: 0.8276 - val_accuracy: 0.6057
# Epoch 26/50
# 46/46 [==============================] - 0s 7ms/step - loss: 0.8271 - accuracy: 0.6088 - val_loss: 0.8235 - val_accuracy: 0.6010
# Epoch 27/50
# 46/46 [==============================] - 0s 7ms/step - loss: 0.8234 - accuracy: 0.6091 - val_loss: 0.8183 - val_accuracy: 0.6098
# Epoch 28/50
# 46/46 [==============================] - 0s 7ms/step - loss: 0.8187 - accuracy: 0.6151 - val_loss: 0.8192 - val_accuracy: 0.6022
# Epoch 29/50
# 46/46 [==============================] - 0s 7ms/step - loss: 0.8179 - accuracy: 0.6135 - val_loss: 0.8115 - val_accuracy: 0.6156
# Epoch 30/50
# 46/46 [==============================] - 0s 8ms/step - loss: 0.8126 - accuracy: 0.6196 - val_loss: 0.8085 - val_accuracy: 0.6203
# Epoch 31/50
# 46/46 [==============================] - 0s 7ms/step - loss: 0.8101 - accuracy: 0.6190 - val_loss: 0.8056 - val_accuracy: 0.6214
# Epoch 32/50
# 46/46 [==============================] - 0s 7ms/step - loss: 0.8079 - accuracy: 0.6258 - val_loss: 0.8035 - val_accuracy: 0.6278
# Epoch 33/50
# 46/46 [==============================] - 0s 9ms/step - loss: 0.8066 - accuracy: 0.6247 - val_loss: 0.8017 - val_accuracy: 0.6232
# Epoch 34/50
# 46/46 [==============================] - 0s 7ms/step - loss: 0.8040 - accuracy: 0.6239 - val_loss: 0.8002 - val_accuracy: 0.6209
# Epoch 35/50
# 46/46 [==============================] - 0s 7ms/step - loss: 0.8024 - accuracy: 0.6274 - val_loss: 0.7985 - val_accuracy: 0.6238
# Epoch 36/50
# 46/46 [==============================] - 0s 7ms/step - loss: 0.8013 - accuracy: 0.6258 - val_loss: 0.7968 - val_accuracy: 0.6238
# Epoch 37/50
# 46/46 [==============================] - 0s 7ms/step - loss: 0.8000 - accuracy: 0.6273 - val_loss: 0.7962 - val_accuracy: 0.6232
# Epoch 38/50
# 46/46 [==============================] - 0s 7ms/step - loss: 0.7986 - accuracy: 0.6282 - val_loss: 0.7976 - val_accuracy: 0.6156
# Epoch 39/50
# 46/46 [==============================] - 0s 8ms/step - loss: 0.7984 - accuracy: 0.6266 - val_loss: 0.7939 - val_accuracy: 0.6191
# Epoch 40/50
# 46/46 [==============================] - 0s 7ms/step - loss: 0.7967 - accuracy: 0.6267 - val_loss: 0.7930 - val_accuracy: 0.6278
# Epoch 41/50
# 46/46 [==============================] - 0s 7ms/step - loss: 0.7958 - accuracy: 0.6309 - val_loss: 0.7922 - val_accuracy: 0.6209
# Epoch 42/50
# 46/46 [==============================] - 0s 7ms/step - loss: 0.7957 - accuracy: 0.6270 - val_loss: 0.7954 - val_accuracy: 0.6209
# Epoch 43/50
# 46/46 [==============================] - 0s 7ms/step - loss: 0.7953 - accuracy: 0.6308 - val_loss: 0.7924 - val_accuracy: 0.6174
# Epoch 44/50
# 46/46 [==============================] - 0s 8ms/step - loss: 0.7942 - accuracy: 0.6308 - val_loss: 0.7905 - val_accuracy: 0.6232
# Epoch 45/50
# 46/46 [==============================] - 0s 8ms/step - loss: 0.7932 - accuracy: 0.6312 - val_loss: 0.7904 - val_accuracy: 0.6243
# Epoch 46/50
# 46/46 [==============================] - 0s 7ms/step - loss: 0.7930 - accuracy: 0.6305 - val_loss: 0.7899 - val_accuracy: 0.6290
# Epoch 47/50
# 46/46 [==============================] - 0s 7ms/step - loss: 0.7925 - accuracy: 0.6314 - val_loss: 0.7897 - val_accuracy: 0.6238
# Epoch 48/50
# 46/46 [==============================] - 0s 7ms/step - loss: 0.7922 - accuracy: 0.6289 - val_loss: 0.7931 - val_accuracy: 0.6144
# Epoch 49/50
# 46/46 [==============================] - 0s 7ms/step - loss: 0.7932 - accuracy: 0.6308 - val_loss: 0.7890 - val_accuracy: 0.6232
# Epoch 50/50
# 46/46 [==============================] - 0s 7ms/step - loss: 0.7912 - accuracy: 0.6314 - val_loss: 0.7887 - val_accuracy: 0.6249
# 68/68 [==============================] - 0s 2ms/step
# ---- building model for batch size of 200
# Epoch 1/50
# 35/35 [==============================] - 1s 14ms/step - loss: 3.6651 - accuracy: 0.2008 - val_loss: 2.9785 - val_accuracy: 0.2464
# Epoch 2/50
# 35/35 [==============================] - 0s 8ms/step - loss: 2.6269 - accuracy: 0.2757 - val_loss: 2.3295 - val_accuracy: 0.3052
# Epoch 3/50
# 35/35 [==============================] - 0s 7ms/step - loss: 2.1915 - accuracy: 0.3311 - val_loss: 2.0447 - val_accuracy: 0.3494
# Epoch 4/50
# 35/35 [==============================] - 0s 9ms/step - loss: 1.9712 - accuracy: 0.3597 - val_loss: 1.8912 - val_accuracy: 0.3669
# Epoch 5/50
# 35/35 [==============================] - 0s 7ms/step - loss: 1.8606 - accuracy: 0.3749 - val_loss: 1.8166 - val_accuracy: 0.3925
# Epoch 6/50
# 35/35 [==============================] - 0s 7ms/step - loss: 1.8009 - accuracy: 0.3902 - val_loss: 1.7662 - val_accuracy: 0.4065
# Epoch 7/50
# 35/35 [==============================] - 0s 8ms/step - loss: 1.7488 - accuracy: 0.3962 - val_loss: 1.7101 - val_accuracy: 0.4065
# Epoch 8/50
# 35/35 [==============================] - 0s 7ms/step - loss: 1.6899 - accuracy: 0.3999 - val_loss: 1.6496 - val_accuracy: 0.4036
# Epoch 9/50
# 35/35 [==============================] - 0s 7ms/step - loss: 1.6266 - accuracy: 0.3950 - val_loss: 1.5827 - val_accuracy: 0.4007
# Epoch 10/50
# 35/35 [==============================] - 0s 7ms/step - loss: 1.5592 - accuracy: 0.3924 - val_loss: 1.5148 - val_accuracy: 0.3949
# Epoch 11/50
# 35/35 [==============================] - 0s 7ms/step - loss: 1.4928 - accuracy: 0.3890 - val_loss: 1.4483 - val_accuracy: 0.3955
# Epoch 12/50
# 35/35 [==============================] - 0s 7ms/step - loss: 1.4270 - accuracy: 0.3927 - val_loss: 1.3850 - val_accuracy: 0.3891
# Epoch 13/50
# 35/35 [==============================] - 0s 7ms/step - loss: 1.3672 - accuracy: 0.3937 - val_loss: 1.3287 - val_accuracy: 0.3931
# Epoch 14/50
# 35/35 [==============================] - 0s 10ms/step - loss: 1.3152 - accuracy: 0.3861 - val_loss: 1.2811 - val_accuracy: 0.3955
# Epoch 15/50
# Epoch 23/50
# 28/28 [==============================] - 0s 9ms/step - loss: 1.1048 - accuracy: 0.4509 - val_loss: 1.0951 - val_accuracy: 0.4566
# Epoch 24/50
# 28/28 [==============================] - 0s 7ms/step - loss: 1.0954 - accuracy: 0.4594 - val_loss: 1.0860 - val_accuracy: 0.4694
# Epoch 25/50
# 28/28 [==============================] - 0s 7ms/step - loss: 1.0871 - accuracy: 0.4652 - val_loss: 1.0778 - val_accuracy: 0.4723
# Epoch 26/50
# 28/28 [==============================] - 0s 7ms/step - loss: 1.0788 - accuracy: 0.4709 - val_loss: 1.0699 - val_accuracy: 0.4764
# Epoch 27/50
# 28/28 [==============================] - 0s 7ms/step - loss: 1.0712 - accuracy: 0.4805 - val_loss: 1.0627 - val_accuracy: 0.4817
# Epoch 28/50
# 28/28 [==============================] - 0s 7ms/step - loss: 1.0644 - accuracy: 0.4865 - val_loss: 1.0560 - val_accuracy: 0.4892
# Epoch 29/50
# 28/28 [==============================] - 0s 7ms/step - loss: 1.0578 - accuracy: 0.4932 - val_loss: 1.0491 - val_accuracy: 0.4933
# Epoch 30/50
# 28/28 [==============================] - 0s 7ms/step - loss: 1.0507 - accuracy: 0.4999 - val_loss: 1.0427 - val_accuracy: 0.5061
# Epoch 31/50
# 28/28 [==============================] - 0s 8ms/step - loss: 1.0445 - accuracy: 0.5086 - val_loss: 1.0367 - val_accuracy: 0.5125
# Epoch 32/50
# 28/28 [==============================] - 0s 7ms/step - loss: 1.0384 - accuracy: 0.5143 - val_loss: 1.0309 - val_accuracy: 0.5178
# Epoch 33/50
# 28/28 [==============================] - 0s 7ms/step - loss: 1.0325 - accuracy: 0.5223 - val_loss: 1.0251 - val_accuracy: 0.5248
# Epoch 34/50
# 28/28 [==============================] - 0s 7ms/step - loss: 1.0265 - accuracy: 0.5300 - val_loss: 1.0197 - val_accuracy: 0.5317
# Epoch 35/50
# 28/28 [==============================] - 0s 7ms/step - loss: 1.0209 - accuracy: 0.5392 - val_loss: 1.0141 - val_accuracy: 0.5411
# Epoch 36/50
# 28/28 [==============================] - 0s 7ms/step - loss: 1.0157 - accuracy: 0.5457 - val_loss: 1.0091 - val_accuracy: 0.5434
# Epoch 37/50
# 28/28 [==============================] - 0s 7ms/step - loss: 1.0101 - accuracy: 0.5508 - val_loss: 1.0039 - val_accuracy: 0.5527
# Epoch 38/50
# 28/28 [==============================] - 0s 7ms/step - loss: 1.0050 - accuracy: 0.5551 - val_loss: 0.9993 - val_accuracy: 0.5539
# Epoch 39/50
# 28/28 [==============================] - 0s 7ms/step - loss: 0.9999 - accuracy: 0.5600 - val_loss: 0.9939 - val_accuracy: 0.5568
# Epoch 40/50
# 28/28 [==============================] - 0s 7ms/step - loss: 0.9949 - accuracy: 0.5652 - val_loss: 0.9891 - val_accuracy: 0.5609
# Epoch 41/50
# 28/28 [==============================] - 0s 8ms/step - loss: 0.9899 - accuracy: 0.5693 - val_loss: 0.9842 - val_accuracy: 0.5632
# Epoch 42/50
# 28/28 [==============================] - 0s 7ms/step - loss: 0.9849 - accuracy: 0.5727 - val_loss: 0.9799 - val_accuracy: 0.5649
# Epoch 43/50
# 28/28 [==============================] - 0s 7ms/step - loss: 0
50
# 23/23 [==============================] - 0s 7ms/step - loss: 1.2304 - accuracy: 0.4040 - val_loss: 1.1855 - val_accuracy: 0.4123
# Epoch 17/50
# 23/23 [==============================] - 0s 8ms/step - loss: 1.1796 - accuracy: 0.4231 - val_loss: 1.1438 - val_accuracy: 0.4199
# Epoch 18/50
# 23/23 [==============================] - 0s 7ms/step - loss: 1.1421 - accuracy: 0.4331 - val_loss: 1.1138 - val_accuracy: 0.4275
# Epoch 19/50
# 23/23 [==============================] - 0s 7ms/step - loss: 1.1139 - accuracy: 0.4394 - val_loss: 1.0905 - val_accuracy: 0.4351
# Epoch 20/50
# 23/23 [==============================] - 0s 8ms/step - loss: 1.0932 - accuracy: 0.4435 - val_loss: 1.0747 - val_accuracy: 0.4391
# Epoch 21/50
# 23/23 [==============================] - 0s 8ms/step - loss: 1.0782 - accuracy: 0.4445 - val_loss: 1.0630 - val_accuracy: 0.4426
# Epoch 22/50
# 23/23 [==============================] - 0s 8ms/step - loss: 1.0671 - accuracy: 0.4473 - val_loss: 1.0540 - val_accuracy: 0.4438
# Epoch 23/50
# 23/23 [==============================] - 0s 7ms/step - loss: 1.0590 - accuracy: 0.4487 - val_loss: 1.0473 - val_accuracy: 0.4415
# Epoch 24/50
# 23/23 [==============================] - 0s 7ms/step - loss: 1.0523 - accuracy: 0.4508 - val_loss: 1.0414 - val_accuracy: 0.4461
# Epoch 25/50
# 23/23 [==============================] - 0s 8ms/step - loss: 1.0467 - accuracy: 0.4502 - val_loss: 1.0362 - val_accuracy: 0.4467
# Epoch 26/50
# 23/23 [==============================] - 0s 7ms/step - loss: 1.0417 - accuracy: 0.4534 - val_loss: 1.0314 - val_accuracy: 0.4490
# Epoch 27/50
# 23/23 [==============================] - 0s 9ms/step - loss: 1.0369 - accuracy: 0.4544 - val_loss: 1.0268 - val_accuracy: 0.4496
# Epoch 28/50
# 23/23 [==============================] - 0s 7ms/step - loss: 1.0327 - accuracy: 0.4543 - val_loss: 1.0230 - val_accuracy: 0.4473
# Epoch 29/50
# 23/23 [==============================] - 0s 8ms/step - loss: 1.0291 - accuracy: 0.4535 - val_loss: 1.0196 - val_accuracy: 0.4496
# Epoch 30/50
# 23/23 [==============================] - 0s 7ms/step - loss: 1.0254 - accuracy: 0.4534 - val_loss: 1.0161 - val_accuracy: 0.4490
# Epoch 31/50
# 23/23 [==============================] - 0s 7ms/step - loss: 1.0224 - accuracy: 0.4562 - val_loss: 1.0133 - val_accuracy: 0.4450
# Epoch 32/50
# 23/23 [==============================] - 0s 7ms/step - loss: 1.0195 - accuracy: 0.4566 - val_loss: 1.0106 - val_accuracy: 0.4479
# Epoch 33/50
# 23/23 [==============================] - 0s 7ms/step - loss: 1.0167 - accuracy: 0.4583 - val_loss: 1.0077 - val_accuracy: 0.4432
# Epoch 34/50
# 23/23 [==============================] - 0s 7ms/step - loss: 1.0140 - accuracy: 0.4581 - val_loss: 1.0054 - val_accuracy: 0.4421
# Epoch 35/50
# 23/23 [==============================] - 0s 7ms/step - loss: 1.0118 - accuracy: 0.4581 - val_loss: 1.0031 - val_accuracy: 0.4438
# Epoch 36/50
# 23/23 [==============================] - 0s 8ms/step - loss: 1.0095 - accuracy: 0.4604 - val_loss: 1.0012 - val_accuracy: 0.4479
# Epoch 37/50
# 23/23 [==============================] - 0s 12ms/step - loss: 1.0076 - accuracy: 0.4605 - val_loss: 0.9992 - val_accuracy: 0.4421
# Epoch 38/50
# 23/23 [==============================] - 0s 8ms/step - loss: 1.0056 - accuracy: 0.4617 - val_loss: 0.9974 - val_accuracy: 0.4397
# Epoch 39/50
# 23/23 [==============================] - 0s 7ms/step - loss: 1.0039 - accuracy: 0.4611 - val_loss: 0.9957 - val_accuracy: 0.4444
# Epoch 40/50
# 23/23 [==============================] - 0s 7ms/step - loss: 1.0022 - accuracy: 0.4632 - val_loss: 0.9944 - val_accuracy: 0.4432
# Epoch 41/50
# 23/23 [==============================] - 0s 7ms/step - loss: 1.0007 - accuracy: 0.4639 - val_loss: 0.9928 - val_accuracy: 0.4438
# Epoch 42/50
# 23/23 [==============================] - 0s 11ms/step - loss: 0.9993 - accuracy: 0.4634 - val_loss: 0.9915 - val_accuracy: 0.4455
# Epoch 43/50
# 23/23 [==============================] - 0s 8ms/step - loss: 0.9978 - accuracy: 0.4607 - val_loss: 0.9899 - val_accuracy: 0.4479
# Epoch 44/50
# 23/23 [==============================] - 0s 7ms/step - loss: 0.9965 - accuracy: 0.4611 - val_loss: 0.9889 - val_accuracy: 0.4467
# Epoch 45/50
# 23/23 [==============================] - 0s 8ms/step - loss: 0.9954 - accuracy: 0.4626 - val_loss: 0.9876 - val_accuracy: 0.4514
# Epoch 46/50
# 23/23 [==============================] - 0s 7ms/step - loss: 0.9942 - accuracy: 0.4618 - val_loss: 0.9867 - val_accuracy: 0.4432
# Epoch 47/50
# 23/23 [==============================] - 0s 7ms/step - loss: 0.9930 - accuracy: 0.4626 - val_loss: 0.9856 - val_accuracy: 0.4485
# Epoch 48/50
# 23/23 [==============================] - 0s 9ms/step - loss: 0.9920 - accuracy: 0.4618 - val_loss: 0.9847 - val_accuracy: 0.4473
# Epoch 49/50
# 23/23 [==============================] - 0s 7ms/step - loss: 0.9912 - accuracy: 0.4607 - val_loss: 0.9838 - val_accuracy: 0.4438
# Epoch 50/50
# 23/23 [==============================] - 0s 7ms/step - loss: 0.9903 - accuracy: 0.4618 - val_loss: 0.9830 - val_accuracy: 0.4444
# 68/68 [==============================] - 0s 2ms/step
# ---- building model for batch size of 350
# Epoch 1/50
# 20/20 [==============================] - 1s 20ms/step - loss: 1.4087 - accuracy: 0.2274 - val_loss: 1.2811 - val_accuracy: 0.2737
# Epoch 2/50
# 20/20 [==============================] - 0s 9ms/step - loss: 1.2215 - accuracy: 0.3286 - val_loss: 1.1648 - val_accuracy: 0.3844
# Epoch 3/50
# 20/20 [==============================] - 0s 12ms/step - loss: 1.1412 - accuracy: 0.4135 - val_loss: 1.1043 - val_accuracy: 0.4310
# Epoch 4/50
# 20/20 [==============================] - 0s 8ms/step - loss: 1.0883 - accuracy: 0.4320 - val_loss: 1.0629 - val_accuracy: 0.4467
# Epoch 5/50
# 20/20 [==============================] - 0s 8ms/step - loss: 1.0542 - accuracy: 0.4548 - val_loss: 1.0386 - val_accuracy: 0.4636
# Epoch 6/50
# 20/20 [==============================] - 0s 10ms/step - loss: 1.0347 - accuracy: 0.4682 - val_loss: 1.0247 - val_accuracy: 0.4700
# Epoch 7/50
# 20/20 [==============================] - 0s 8ms/step - loss: 1.0237 - accuracy: 0.4719 - val_loss: 1.0157 - val_accuracy: 0.4752
# Epoch 8/50
# 20/20 [==============================] - 0s 8ms/step - loss: 1.0154 - accuracy: 0.4691 - val_loss: 1.0083 - val_accuracy: 0.4712
# Epoch 9/50
# 20/20 [==============================] - 0s 8ms/step - loss: 1.0093 - accuracy: 0.4674 - val_loss: 1.0028 - val_accuracy: 0.4787
# Epoch 10/50
# 20/20 [==============================] - 0s 8ms/step - loss: 1.0041 - accuracy: 0.4669 - val_loss: 0.9979 - val_accuracy: 0.4706
# Epoch 11/50
# 20/20 [==============================] - 0s 8ms/step - loss: 1.0002 - accuracy: 0.4719 - val_loss: 0.9941 - val_accuracy: 0.4624
# Epoch 12/50
# 20/20 [==============================] - 0s 8ms/step - loss: 0.9965 - accuracy: 0.4675 - val_loss: 0.9904 - val_accuracy: 0.4613
# Epoch 13/50
# 20/20 [==============================] - 0s 8ms/step - loss: 0.9934 - accuracy: 0.4637 - val_loss: 0.9876 - val_accuracy: 0.4619
# Epoch 14/50
# 20/20 [==============================] - 0s 8ms/step - loss: 0.9909 - accuracy: 0.4639 - val_loss: 0.9851 - val_accuracy: 0.4572
# Epoch 15/50
# 20/20 [==============================] - 0s 8ms/step - loss: 0.9887 - accuracy: 0.4598 - val_loss: 0.9831 - val_accuracy: 0.4531
# Epoch 16/50
# 20/20 [==============================] - 0s 7ms/step - loss: 0.9868 - accuracy: 0.4575 - val_loss: 0.9809 - val_accuracy: 0.4549
# Epoch 17/50
# 20/20 [==============================] - 0s 7ms/step - loss: 0.9851 - accuracy: 0.4559 - val_loss: 0.9791 - val_accuracy: 0.4520
# Epoch 18/50
# 20/20 [==============================] - 0s 8ms/step - loss: 0.9836 - accuracy: 0.4543 - val_loss: 0.9778 - val_accuracy: 0.4461
# Epoch 19/50
# 20/20 [==============================] - 0s 7ms/step - loss: 0.9821 - accuracy: 0.4465 - val_loss: 0.9758 - val_accuracy: 0.4485
# Epoch 20/50
# 20/20 [==============================] - 0s 8ms/step - loss: 0.9807 - accuracy: 0.4480 - val_loss: 0.9744 - val_accuracy: 0.4455
# Epoch 21/50
# 20/20 [==============================] - 0s 8ms/step - loss: 0.9793 - accuracy: 0.4464 - val_loss: 0.9727 - val_accuracy: 0.4380
# Epoch 22/50
# 20/20 [==============================] - 0s 8ms/step - loss: 0.9779 - accuracy: 0.4432 - val_loss: 0.9711 - val_accuracy: 0.4368
# Epoch 23/50
# 20/20 [==============================] - 0s 10ms/step - loss: 0.9763 - accuracy: 0.4394 - val_loss: 0.9694 - val_accuracy: 0.4339
# Epoch 24/50
# 20/20 [==============================] - 0s 7ms/step - loss: 0.9748 - accuracy: 0.4349 - val_loss: 0.9677 - val_accuracy: 0.4316
# Epoch 25/50
# 20/20 [==============================] - 0s 7ms/step - loss: 0.9734 - accuracy: 0.4324 - val_loss: 0.9654 - val_accuracy: 0.4316
# Epoch 26/50
# 20/20 [==============================] - 0s 7ms/step - loss: 0.9714 - accuracy: 0.4286 - val_loss: 0.9634 - val_accuracy: 0.4199
# Epoch 27/50
# 20/20 [==============================] - 0s 7ms/step - loss: 0.9693 - accuracy: 0.4269 - val_loss: 0.9611 - val_accuracy: 0.4222
# Epoch 28/50
# 20/20 [==============================] - 0s 8ms/step - loss: 0.9670 - accuracy: 0.4259 - val_loss: 0.9584 - val_accuracy: 0.4252
# Epoch 29/50
# 20/20 [==============================] - 0s 8ms/step - loss: 0.9645 - accuracy: 0.4257 - val_loss: 0.9553 - val_accuracy: 0.4234
# Epoch 30/50
# 20/20 [==============================] - 0s 8ms/step - loss: 0.9617 - accuracy: 0.4259 - val_loss: 0.9518 - val_accuracy: 0.4281
# Epoch 31/50
# 20/20 [==============================] - 0s 8ms/step - loss: 0.9584 - accuracy: 0.4285 - val_loss: 0.9482 - val_accuracy: 0.4310
# Epoch 32/50
# 20/20 [==============================] - 0s 7ms/step - loss: 0.9548 - accuracy: 0.4324 - val_loss: 0.9438 - val_accuracy: 0.4432
# Epoch 33/50
# 20/20 [==============================] - 0s 8ms/step - loss: 0.9506 - accuracy: 0.4390 - val_loss: 0.9389 - val_accuracy: 0.4549
# Epoch 34/50
# 20/20 [==============================] - 0s 7ms/step - loss: 0.9465 - accuracy: 0.4524 - val_loss: 0.9340 - val_accuracy: 0.4630
# Epoch 35/50
# 20/20 [==============================] - 0s 8ms/step - loss: 0.9414 - accuracy: 0.4639 - val_loss: 0.9285 - val_accuracy: 0.4770
# Epoch 36/50
# ...
# Epoch 43/50
# 8/8 [==============================] - 0s 9ms/step - loss: 2.3363 - accuracy: 0.1538 - val_loss: 2.3393 - val_accuracy: 0.1637
# Epoch 44/50
# 8/8 [==============================] - 0s 9ms/step - loss: 2.2765 - accuracy: 0.1719 - val_loss: 2.2816 - val_accuracy: 0.1875
# Epoch 45/50
# 8/8 [==============================] - 0s 10ms/step - loss: 2.2175 - accuracy: 0.1969 - val_loss: 2.2227 - val_accuracy: 0.2062
# Epoch 46/50
# 8/8 [==============================] - 0s 9ms/step - loss: 2.1585 - accuracy: 0.2260 - val_loss: 2.1652 - val_accuracy: 0.2347
# Epoch 47/50
# 8/8 [==============================] - 0s 10ms/step - loss: 2.1058 - accuracy: 0.2549 - val_loss: 2.1163 - val_accuracy: 0.2632
# Epoch 48/50
# 8/8 [==============================] - 0s 9ms/step - loss: 2.0591 - accuracy: 0.2881 - val_loss: 2.0723 - val_accuracy: 0.3052
# Epoch 49/50
# 8/8 [==============================] - 0s 10ms/step - loss: 2.0164 - accuracy: 0.3293 - val_loss: 2.0305 - val_accuracy: 0.3430
# Epoch 50/50
# 8/8 [==============================] - 0s 9ms/step - loss: 1.9742 - accuracy: 0.3634 - val_loss: 1.9883 - val_accuracy: 0.3774
# 68/68 [==============================] - 0s 2ms/step
# ---- building model for batch size of 950
# Epoch 1/50
# 8/8 [==============================] - 1s 44ms/step - loss: 1.8437 - accuracy: 0.3985 - val_loss: 1.8171 - val_accuracy: 0.3867
# Epoch 2/50
# 8/8 [==============================] - 0s 15ms/step - loss: 1.7999 - accuracy: 0.3861 - val_loss: 1.8132 - val_accuracy: 0.3809
# Epoch 3/50
# 8/8 [==============================] - 0s 12ms/step - loss: 1.7956 - accuracy: 0.3838 - val_loss: 1.8204 - val_accuracy: 0.3955
# Epoch 4/50
# 8/8 [==============================] - 0s 11ms/step - loss: 1.8003 - accuracy: 0.3858 - val_loss: 1.8211 - val_accuracy: 0.3873
# Epoch 5/50
# 8/8 [==============================] - 0s 11ms/step - loss: 1.7884 - accuracy: 0.3900 - val_loss: 1.7935 - val_accuracy: 0.3949
# Epoch 6/50
# 8/8 [==============================] - 0s 16ms/step - loss: 1.7544 - accuracy: 0.3970 - val_loss: 1.7485 - val_accuracy: 0.4024
# Epoch 7/50
# 8/8 [==============================] - 0s 10ms/step - loss: 1.6985 - accuracy: 0.4049 - val_loss: 1.6776 - val_accuracy: 0.4129
# Epoch 8/50
# 8/8 [==============================] - 0s 11ms/step - loss: 1.6266 - accuracy: 0.4149 - val_loss: 1.6012 - val_accuracy: 0.4252
# Epoch 9/50
# 8/8 [==============================] - 0s 10ms/step - loss: 1.5471 - accuracy: 0.4212 - val_loss: 1.5144 - val_accuracy: 0.4380
# Epoch 10/50
# 8/8 [==============================] - 0s 21ms/step - loss: 1.4638 - accuracy: 0.4362 - val_loss: 1.4309 - val_accuracy: 0.4619
# Epoch 11/50
# 8/8 [==============================] - 0s 12ms/step - loss: 1.3858 - accuracy: 0.4500 - val_loss: 1.3542 - val_accuracy: 0.4712
# Epoch 12/50
# 8/8 [==============================] - 0s 10ms/step - loss: 1.3163 - accuracy: 0.4742 - val_loss: 1.2892 - val_accuracy: 0.4834
# Epoch 13/50
# 8/8 [==============================] - 0s 9ms/step - loss: 1.2618 - accuracy: 0.4889 - val_loss: 1.2448 - val_accuracy: 0.4921
# Epoch 14/50
# 8/8 [==============================] - 0s 11ms/step - loss: 1.2253 - accuracy: 0.4945 - val_loss: 1.2124 - val_accuracy: 0.4956
# Epoch 15/50
# 8/8 [==============================] - 0s 12ms/step - loss: 1.1955 - accuracy: 0.4983 - val_loss: 1.1868 - val_accuracy: 0.4991
# Epoch 16/50
# 8/8 [==============================] - 0s 9ms/step - loss: 1.1710 - accuracy: 0.5028 - val_loss: 1.1631 - val_accuracy: 0.5026
# Epoch 17/50
# 8/8 [==============================] - 0s 9ms/step - loss: 1.1482 - accuracy: 0.5071 - val_loss: 1.1414 - val_accuracy: 0.5096
# Epoch 18/50
# 8/8 [==============================] - 0s 10ms/step - loss: 1.1290 - accuracy: 0.5092 - val_loss: 1.1241 - val_accuracy: 0.5172
# Epoch 19/50
# 8/8 [==============================] - 0s 9ms/step - loss: 1.1137 - accuracy: 0.5122 - val_loss: 1.1089 - val_accuracy: 0.5201
# Epoch 20/50
# 8/8 [==============================] - 0s 9ms/step - loss: 1.1000 - accuracy: 0.5151 - val_loss: 1.0969 - val_accuracy: 0.5178
# Epoch 21/50
# 8/8 [==============================] - 0s 10ms/step - loss: 1.0887 - accuracy: 0.5192 - val_loss: 1.0859 - val_accuracy: 0.5166
# Epoch 22/50
# 8/8 [==============================] - 0s 9ms/step - loss: 1.0781 - accuracy: 0.5218 - val_loss: 1.0753 - val_accuracy: 0.5236
# Epoch 23/50
# 8/8 [==============================] - 0s 15ms/step - loss: 1.0689 - accuracy: 0.5236 - val_loss: 1.0664 - val_accuracy: 0.5323
# Epoch 24/50
# 8/8 [==============================] - 0s 13ms/step - loss: 1.0601 - accuracy: 0.5277 - val_loss: 1.0585 - val_accuracy: 0.5306
# Epoch 25/50
# 8/8 [==============================] - 0s 9ms/step - loss: 1.0519 - accuracy: 0.5331 - val_loss: 1.0502 - val_accuracy: 0.5341
# Epoch 26/50
# 8/8 [==============================] - 0s 10ms/step - loss: 1.0450 - accuracy: 0.5379 - val_loss: 1.0433 - val_accuracy: 0.5329
# Epoch 27/50
# 8/8 [==============================] - 0s 9ms/step - loss: 1.0383 - accuracy: 0.5422 - val_loss: 1.0374 - val_accuracy: 0.5381
# Epoch 28/50
# 8/8 [==============================] - 0s 10ms/step - loss: 1.0324 - accuracy: 0.5444 - val_loss: 1.0318 - val_accuracy: 0.5381
# Epoch 29/50
# 8/8 [==============================] - 0s 9ms/step - loss: 1.0276 - accuracy: 0.5462 - val_loss: 1.0272 - val_accuracy: 0.5358
# Epoch 30/50
# 8/8 [==============================] - 0s 10ms/step - loss: 1.0233 - accuracy: 0.5479 - val_loss: 1.0232 - val_accuracy: 0.5399
# Epoch 31/50
# 8/8 [==============================] - 0s 9ms/step - loss: 1.0192 - accuracy: 0.5508 - val_loss: 1.0191 - val_accuracy: 0.5422
# Epoch 32/50
# 8/8 [==============================] - 0s 9ms/step - loss: 1.0152 - accuracy: 0.5526 - val_loss: 1.0150 - val_accuracy: 0.5504
# Epoch 33/50
# 8/8 [==============================] - 0s 9ms/step - loss: 1.0112 - accuracy: 0.5553 - val_loss: 1.0110 - val_accuracy: 0.5475
# Epoch 34/50
# 8/8 [==============================] - 0s 9ms/step - loss: 1.0081 - accuracy: 0.5587 - val_loss: 1.0085 - val_accuracy: 0.5498
# Epoch 35/50
# 8/8 [==============================] - 0s 9ms/step - loss: 1.0046 - accuracy: 0.5597 - val_loss: 1.0045 - val_accuracy: 0.5480
# Epoch 36/50
# 8/8 [==============================] - 0s 12ms/step - loss: 1.0015 - accuracy: 0.5593 - val_loss: 1.0016 - val_accuracy: 0.5515
# Epoch 37/50
# 8/8 [==============================] - 0s 15ms/step - loss: 0.9985 - accuracy: 0.5603 - val_loss: 0.9982 - val_accuracy: 0.5539
# Epoch 38/50
# 8/8 [==============================] - 0s 9ms/step - loss: 0.9948 - accuracy: 0.5634 - val_loss: 0.9944 - val_accuracy: 0.5521
# Epoch 39/50
# 8/8 [==============================] - 0s 9ms/step - loss: 0.9912 - accuracy: 0.5683 - val_loss: 0.9917 - val_accuracy: 0.5574
# Epoch 40/50
# 8/8 [==============================] - 0s 9ms/step - loss: 0.9884 - accuracy: 0.5687 - val_loss: 0.9887 - val_accuracy: 0.5579
# Epoch 41/50
# 8/8 [==============================] - 0s 9ms/step - loss: 0.9860 - accuracy: 0.5693 - val_loss: 0.9858 - val_accuracy: 0.5550
# Epoch 42/50
# 8/8 [==============================] - 0s 9ms/step - loss: 0.9828 - accuracy: 0.5705 - val_loss: 0.9825 - val_accuracy: 0.5579
# Epoch 43/50
# 8/8 [==============================] - 0s 9ms/step - loss: 0.9799 - accuracy: 0.5719 - val_loss: 0.9798 - val_accuracy: 0.5574
# Epoch 44/50
# 8/8 [==============================] - 0s 9ms/step - loss: 0.9769 - accuracy: 0.5725 - val_loss: 0.9771 - val_accuracy: 0.5609
# Epoch 45/50
# 8/8 [==============================] - 0s 9ms/step - loss: 0.9743 - accuracy: 0.5736 - val_loss: 0.9746 - val_accuracy: 0.5620
# Epoch 46/50
# 8/8 [==============================] - 0s 24ms/step - loss: 0.9715 - accuracy: 0.5752 - val_loss: 0.9718 - val_accuracy: 0.5655
# Epoch 47/50
# 8/8 [==============================] - 0s 9ms/step - loss: 0.9690 - accuracy: 0.5762 - val_loss: 0.9700 - val_accuracy: 0.5649
# Epoch 48/50
# 8/8 [==============================] - 0s 9ms/step - loss: 0.9677 - accuracy: 0.5769 - val_loss: 0.9678 - val_accuracy: 0.5684
# Epoch 49/50
# 8/8 [==============================] - 0s 11ms/step - loss: 0.9643 - accuracy: 0.5775 - val_loss: 0.9645 - val_accuracy: 0.5679
# Epoch 50/50
# 8/8 [==============================] - 0s 17ms/step - loss: 0.9613 - accuracy: 0.5770 - val_loss: 0.9619 - val_accuracy: 0.5708
# 68/68 [==============================] - 0s 2ms/step
# ---- building model for batch size of 1000
# Epoch 1/50
# 7/7 [==============================] - 1s 56ms/step - loss: 2.1380 - accuracy: 0.0920 - val_loss: 2.1210 - val_accuracy: 0.1002
# Epoch 2/50
# 7/7 [==============================] - 0s 15ms/step - loss: 2.1233 - accuracy: 0.1126 - val_loss: 2.1035 - val_accuracy: 0.1217
# Epoch 3/50
# 7/7 [==============================] - 0s 12ms/step - loss: 2.1005 - accuracy: 0.1260 - val_loss: 2.0713 - val_accuracy: 0.1322
# Epoch 4/50
# 7/7 [==============================] - 0s 11ms/step - loss: 2.0615 - accuracy: 0.1362 - val_loss: 2.0232 - val_accuracy: 0.1404
# Epoch 5/50
# 7/7 [==============================] - 0s 15ms/step - loss: 2.0093 - accuracy: 0.1438 - val_loss: 1.9652 - val_accuracy: 0.1474
# Epoch 6/50
# 7/7 [==============================] - 0s 15ms/step - loss: 1.9507 - accuracy: 0.1646 - val_loss: 1.9061 - val_accuracy: 0.1776
# Epoch 7/50
# 7/7 [==============================] - 0s 11ms/step - loss: 1.8930 - accuracy: 0.1927 - val_loss: 1.8501 - val_accuracy: 0.2137
# Epoch 8/50
# 7/7 [==============================] - 0s 10ms/step - loss: 1.8391 - accuracy: 0.2348 - val_loss: 1.7979 - val_accuracy: 0.2574
# Epoch 9/50
# 7/7 [==============================] - 0s 13ms/step - loss: 1.7888 - accuracy: 0.2855 - val_loss: 1.7496 - val_accuracy: 0.3128
# Epoch 10/50
# 7/7 [==============================] - 0s 10ms/step - loss: 1.7418 - accuracy: 0.3360 - val_loss: 1.7036 - val_accuracy: 0.3512
# Epoch 11/50
# 7/7 [==============================] - 0s 10ms/step - loss: 1.6967 - accuracy: 0.3667 - val_loss: 1.6600 - val_accuracy: 0.3826
# Epoch 12/50
# 7/7 [==============================] - 0s 23ms/step - loss: 1.6534 - accuracy: 0.3877 - val_loss: 1.6176 - val_accuracy: 0.4007
# Epoch 13/50
# 7/7 [==============================] - 0s 11ms/step - loss: 1.6114 - accuracy: 0.3998 - val_loss: 1.5770 - val_accuracy: 0.4135
# Epoch 14/50
# 7/7 [==============================] - 0s 11ms/step - loss: 1.5708 - accuracy: 0.4084 - val_loss: 1.5364 - val_accuracy: 0.4188
# Epoch 15/50
# 7/7 [==============================] - 0s 11ms/step - loss: 1.5303 - accuracy: 0.4130 - val_loss: 1.4978 - val_accuracy: 0.4292
# Epoch 16/50
# 7/7 [==============================] - 0s 11ms/step - loss: 1.4916 - accuracy: 0.4165 - val_loss: 1.4601 - val_accuracy: 0.4269
# Epoch 17/50
# 7/7 [==============================] - 0s 10ms/step - loss: 1.4541 - accuracy: 0.4186 - val_loss: 1.4244 - val_accuracy: 0.4298
# Epoch 18/50
# 7/7 [==============================] - 0s 14ms/step - loss: 1.4190 - accuracy: 0.4209 - val_loss: 1.3901 - val_accuracy: 0.4287
# Epoch 19/50
# 7/7 [==============================] - 0s 11ms/step - loss: 1.3851 - accuracy: 0.4218 - val_loss: 1.3578 - val_accuracy: 0.4327
# Epoch 20/50
# 7/7 [==============================] - 0s 11ms/step - loss: 1.3532 - accuracy: 0.4225 - val_loss: 1.3273 - val_accuracy: 0.4321
# Epoch 21/50
# 7/7 [==============================] - 0s 11ms/step - loss: 1.3234 - accuracy: 0.4228 - val_loss: 1.2992 - val_accuracy: 0.4333
# Epoch 22/50
# 7/7 [==============================] - 0s 10ms/step - loss: 1.2958 - accuracy: 0.4262 - val_loss: 1.2727 - val_accuracy: 0.4321
# Epoch 23/50
# 7/7 [==============================] - 0s 10ms/step - loss: 1.2700 - accuracy: 0.4298 - val_loss: 1.2485 - val_accuracy: 0.4415
# Epoch 24/50
# 7/7 [==============================] - 0s 11ms/step - loss: 1.2467 - accuracy: 0.4339 - val_loss: 1.2263 - val_accuracy: 0.4444
# Epoch 25/50
# 7/7 [==============================] - 0s 10ms/step - loss: 1.2251 - accuracy: 0.4371 - val_loss: 1.2064 - val_accuracy: 0.4391
# Epoch 26/50
# 7/7 [==============================] - 0s 10ms/step - loss: 1.2054 - accuracy: 0.4388 - val_loss: 1.1880 - val_accuracy: 0.4380
# Epoch 27/50
# 7/7 [==============================] - 0s 10ms/step - loss: 1.1879 - accuracy: 0.4390 - val_loss: 1.1712 - val_accuracy: 0.4368
# Epoch 28/50
# 7/7 [==============================] - 0s 10ms/step - loss: 1.1719 - accuracy: 0.4404 - val_loss: 1.1560 - val_accuracy: 0.4345
# Epoch 29/50
# 7/7 [==============================] - 0s 14ms/step - loss: 1.1574 - accuracy: 0.4407 - val_loss: 1.1426 - val_accuracy: 0.4316
# Epoch 30/50
# 7/7 [==============================] - 0s 12ms/step - loss: 1.1443 - accuracy: 0.4412 - val_loss: 1.1308 - val_accuracy: 0.4345
# Epoch 31/50
# 7/7 [==============================] - 0s 10ms/step - loss: 1.1334 - accuracy: 0.4390 - val_loss: 1.1201 - val_accuracy: 0.4386
# Epoch 32/50
# 7/7 [==============================] - 0s 10ms/step - loss: 1.1231 - accuracy: 0.4369 - val_loss: 1.1108 - val_accuracy: 0.4386
# Epoch 33/50
# 7/7 [==============================] - 0s 10ms/step - loss: 1.1144 - accuracy: 0.4371 - val_loss: 1.1027 - val_accuracy: 0.4397
# Epoch 34/50
# 7/7 [==============================] - 0s 10ms/step - loss: 1.1066 - accuracy: 0.4371 - val_loss: 1.0955 - val_accuracy: 0.4403
# Epoch 35/50
# 7/7 [==============================] - 0s 10ms/step - loss: 1.0997 - accuracy: 0.4368 - val_loss: 1.0892 - val_accuracy: 0.4397
# Epoch 36/50
# 7/7 [==============================] - 0s 10ms/step - loss: 1.0939 - accuracy: 0.4375 - val_loss: 1.0835 - val_accuracy: 0.4409
# Epoch 37/50
# 7/7 [==============================] - 0s 9ms/step - loss: 1.0885 - accuracy: 0.4358 - val_loss: 1.0786 - val_accuracy: 0.4432
# Epoch 38/50
# 7/7 [==============================] - 0s 10ms/step - loss: 1.0838 - accuracy: 0.4356 - val_loss: 1.0742 - val_accuracy: 0.4432
# Epoch 39/50
# 7/7 [==============================] - 0s 10ms/step - loss: 1.0797 - accuracy: 0.4366 - val_loss: 1.0703 - val_accuracy: 0.4444
# Epoch 40/50
# 7/7 [==============================] - 0s 9ms/step - loss: 1.0760 - accuracy: 0.4369 - val_loss: 1.0668 - val_accuracy: 0.4415
# Epoch 41/50
# 7/7 [==============================] - 0s 9ms/step - loss: 1.0727 - accuracy: 0.4362 - val_loss: 1.0638 - val_accuracy: 0.4409
# Epoch 42/50
# 7/7 [==============================] - 0s 10ms/step - loss: 1.0698 - accuracy: 0.4366 - val_loss: 1.0610 - val_accuracy: 0.4421
# Epoch 43/50
# 7/7 [==============================] - 0s 18ms/step - loss: 1.0671 - accuracy: 0.4375 - val_loss: 1.0585 - val_accuracy: 0.4391
# Epoch 44/50
# 7/7 [==============================] - 0s 10ms/step - loss: 1.0647 - accuracy: 0.4378 - val_loss: 1.0563 - val_accuracy: 0.4374
# Epoch 45/50
# 7/7 [==============================] - 0s 10ms/step - loss: 1.0626 - accuracy: 0.4387 - val_loss: 1.0542 - val_accuracy: 0.4374
# Epoch 46/50
# 7/7 [==============================] - 0s 10ms/step - loss: 1.0605 - accuracy: 0.4384 - val_loss: 1.0523 - val_accuracy: 0.4374
# Epoch 47/50
# 7/7 [==============================] - 0s 10ms/step - loss: 1.0587 - accuracy: 0.4381 - val_loss: 1.0506 - val_accuracy: 0.4368
# Epoch 48/50
# 7/7 [==============================] - 0s 10ms/step - loss: 1.0570 - accuracy: 0.4377 - val_loss: 1.0489 - val_accuracy: 0.4368
# Epoch 49/50
# 7/7 [==============================] - 0s 9ms/step - loss: 1.0554 - accuracy: 0.4371 - val_loss: 1.0475 - val_accuracy: 0.4362
# Epoch 50/50
# 7/7 [==============================] - 0s 10ms/step - loss: 1.0540 - accuracy: 0.4381 - val_loss: 1.0461 - val_accuracy: 0.4374
# 68/68 [==============================] - 0s 2ms/step
#     Batch Size  Metrics Value         Metrics Type
# 0            1       0.628022  Validation Accuracy
# 1            1       0.991779            Test Loss
# 2            1       0.477633        Test Accuracy
# 3            1       0.453491   Test ROC-AUC Score
# 4           50       0.378823  Validation Accuracy
# ..         ...            ...                  ...
# 79         950       0.521291   Test ROC-AUC Score
# 80        1000       0.397320  Validation Accuracy
# 81        1000       3.120471            Test Loss
# 82        1000       0.405871        Test Accuracy
# 83        1000       0.543357   Test ROC-AUC Score
#
# [84 rows x 3 columns]

# %%
accuracy_only = results[(results["Metrics Type"] == "Test Accuracy") | (results["Metrics Type"] == "Validation Accuracy")]
accuracy_only
# Out:
#     Batch Size  Metrics Value         Metrics Type
# 0            1       0.628022  Validation Accuracy
# 2            1       0.477633        Test Accuracy
# 4           50       0.378823  Validation Accuracy
# 6           50       0.404007        Test Accuracy
# 8          100       0.438392  Validation Accuracy
# 10         100       0.453868        Test Accuracy
# 12         150       0.178707  Validation Accuracy
# 14         150       0.237185        Test Accuracy
# 16         200       0.394116  Validation Accuracy
# 18         200       0.432898        Test Accuracy
# 20         250       0.473638  Validation Accuracy
# 22         250       0.470177        Test Accuracy
# 24         300       0.409117  Validation Accuracy
# 26         300       0.402609        Test Accuracy
# 28         350       0.352607  Validation Accuracy
# 30         350       0.383504        Test Accuracy
# 32         400       0.443053  Validation Accuracy
# 34         400       0.445480        Test Accuracy
# 36         450       0.409263  Validation Accuracy
# 38         450       0.392358        Test Accuracy
# 40         500       0.135304  Validation Accuracy
# 42         500       0.143057        Test Accuracy
# 44         550       0.430964  Validation Accuracy
# 46         550       0.438490        Test Accuracy
# 48         600       0.364987  Validation Accuracy
# 50         600       0.410065        Test Accuracy
# 52         650       0.366735  Validation Accuracy
# 54         650       0.366263        Test Accuracy
# 56         700       0.138946  Validation Accuracy
# 58         700       0.232526        Test Accuracy
# 60         750       0.003495  Validation Accuracy
# 62         750       0.020969        Test Accuracy
# 64         800       0.356976  Validation Accuracy
# 66         800       0.438024        Test Accuracy
# 68         850       0.444218  Validation Accuracy
# 70         850       0.441286        Test Accuracy
# 72         900       0.127294  Validation Accuracy
# 74         900       0.130941        Test Accuracy
# 76         950       0.380571  Validation Accuracy
# 78         950       0.453868        Test Accuracy
# 80        1000       0.397320  Validation Accuracy
# 82        1000       0.405871        Test Accuracy

# %%
sns.lineplot(accuracy_only, 
             x = "Batch Size",
             y = "Metrics Value",
             hue = "Metrics Type"
             )
# Out:
# <Axes: xlabel='Batch Size', ylabel='Metrics Value'>

# %%
roc_auc_only = results[results["Metrics Type"] == "Test ROC-AUC Score"]
roc_auc_only
# Out:
#     Batch Size  Metrics Value        Metrics Type
# 3            1       0.453491  Test ROC-AUC Score
# 7           50       0.535898  Test ROC-AUC Score
# 11         100       0.508895  Test ROC-AUC Score
# 15         150       0.488812  Test ROC-AUC Score
# 19         200       0.540664  Test ROC-AUC Score
# 23         250       0.493407  Test ROC-AUC Score
# 27         300       0.503998  Test ROC-AUC Score
# 31         350       0.548370  Test ROC-AUC Score
# 35         400       0.439734  Test ROC-AUC Score
# 39         450       0.541227  Test ROC-AUC Score
# 43         500       0.493445  Test ROC-AUC Score
# 47         550       0.505522  Test ROC-AUC Score
# 51         600       0.559591  Test ROC-AUC Score
# 55         650       0.453371  Test ROC-AUC Score
# 59         700       0.488926  Test ROC-AUC Score
# 63         750       0.498141  Test ROC-AUC Score
# 67         800       0.543790  Test ROC-AUC Score
# 71         850       0.451591  Test ROC-AUC Score
# 75         900       0.487236  Test ROC-AUC Score
# 79         950       0.521291  Test ROC-AUC Score
# 83        1000       0.543357  Test ROC-AUC Score

# %%
sns.lineplot(roc_auc_only, 
             x = "Batch Size",
             y = "Metrics Value"
             )
# Out:
# <Axes: xlabel='Batch Size', ylabel='Metrics Value'>
